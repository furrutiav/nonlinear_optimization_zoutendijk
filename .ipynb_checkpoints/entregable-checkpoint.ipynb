# %% [markdown]
# # MA5701 Optimización no lineal: Tarea 3
# **Fecha de entrega:** 4 de Julio a las 23:59 hrs.
#
# **Profesor:** Jorge G. Amaya A.
#
# **Auxiliar:** Aldo Gutiérrez Concha.
#
# **Ayudantes:** Carolina Chiu y Mariano Vazquez.
#
# **Autor:** Felipe Urrutia Vargas

# %%
from scipy.optimize import linprog
import numpy as np
# !pip install numdifftools
import numdifftools as nd
import re
import pandas as pd
import time
# Out:
# Requirement already satisfied: numdifftools in c:\users\felip\anaconda3\lib\site-packages (0.9.40)
# Requirement already satisfied: scipy>=0.8 in c:\users\felip\anaconda3\lib\site-packages (from numdifftools) (1.6.2)
# Requirement already satisfied: algopy>=0.4 in c:\users\felip\anaconda3\lib\site-packages (from numdifftools) (0.5.7)
# Requirement already satisfied: statsmodels>=0.6 in c:\users\felip\anaconda3\lib\site-packages (from numdifftools) (0.12.2)
# Requirement already satisfied: numpy>=1.9 in c:\users\felip\anaconda3\lib\site-packages (from numdifftools) (1.20.3)
# Requirement already satisfied: pandas>=0.21 in c:\users\felip\anaconda3\lib\site-packages (from statsmodels>=0.6->numdifftools) (1.4.2)
# Requirement already satisfied: patsy>=0.5 in c:\users\felip\anaconda3\lib\site-packages (from statsmodels>=0.6->numdifftools) (0.5.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\felip\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels>=0.6->numdifftools) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\felip\anaconda3\lib\site-packages (from pandas>=0.21->statsmodels>=0.6->numdifftools) (2.8.2)
# Requirement already satisfied: six in c:\users\felip\appdata\roaming\python\python38\site-packages (from patsy>=0.5->statsmodels>=0.6->numdifftools) (1.14.0)

# %% [markdown]
# #  Método de direcciones admisibles (Zoutendijk)

# %% [markdown]
# Resolver el problema de optimización no lineal:
# $$(P) \quad \begin{cases} \min &f (x) \\
# s.a. &Ax \leq b \\
# &Ex = e
# \end{cases}$$

# %% [markdown]
# ## Paso 0

# %%
def step0(xk, A, b, E=None, e=None):
    """
    Funcion que evalua la factibilidad del punto xk 
    en el poliedro definido por {x : Ax<=b, Ex=e}.
    
    Parametros
    ----------
    xk : np.array (n, 1)
        Punto a evaluar
    A : np.array (m_A, n)
        Coef. de las restr. de desigualdad
    b : np.array (m_A, 1)
        Lado derecho de las restr. de desigualdad
    E : default=None; np.array (m_E, n)
        Coef. de las restr. de igualdad
    e : default=None; np.array (m_E, 1)
        Lado derecho de las restr. de igualdad
    """
    feasible = np.all(A@xk <= b)
    if str(E) != "None":
        feasible = feasible and np.all(np.isclose(E@xk, e))
    return feasible

# %% [markdown]
# ## Paso 1

# %%
def step1(xk, A, b, verbose=False, k=-1):
    """
    Funcion que descompone las restricciones de 
    desigualdad (Ax<=b) en aquellas que son activas 
    (A1 x = b1) y las que NO (A2 x < b2), donde 
    A = [A1 | A2] y b = [b1 | b2]
    
    Parametros
    ----------
    xk : np.array (n, 1)
        Punto a evaluar
    A : np.array (m_A, n)
        Coef. de las restr. de desigualdad
    b : np.array (m_A, 1)
        Lado derecho de las restr. de desigualdad
    """
    index_A1 = np.isclose(A@xk, b)
    index_A2 = ~index_A1

    A1 = A[index_A1]
    A2 = A[index_A2]

    b1 = b[index_A1]
    b2 = b[index_A2]
    
    if verbose:
        print(f"(step=1, k={k}) A1.index: {index_A1}")
        print(f"(step=1, k={k}) A2.index: {index_A2}")
    return A1, A2, b1, b2

# %% [markdown]
# ## Paso 2

# %%
def step2(obj, A1, E, eps, method="simplex", verbose=False, k=-1):
    """
    Funcion que resuelve el problema lineal (Dk)
    definido por:
    (Dk) |  min <obj, d>
         |  s.a A1d <= 0
         |       Ed  = 0
    con dk la solucion optima.     
         
    Parametros
    ----------
    obj : np.array (n, 1)
        Costos de la funcion lineal objetivo (grad f(xk))
    A1 : np.array (m_A1, n)
        Coef. de las restr. de desigualdad activas
    E : np.array (m_E, n)
        Coef. de las restr. de igualdad
    eps : float
        Tolerancia para chequear que |obj * dk| sea pequeño
    """
    lhs_ineq = A1
    rhs_ineq = np.zeros(A1.shape[0]) if str(A1) != "None" else None

    lhs_eq = E
    rhs_eq = np.zeros(E.shape[0]) if str(E) != "None" else None

    bnd = [(-1, 1) for _ in range(obj.shape[0])] 

    opt = linprog(c=obj, A_ub=lhs_ineq, b_ub=rhs_ineq,
                  A_eq=lhs_eq, b_eq=rhs_eq, bounds=bnd,
                  method=method)
    dk = opt.x
    stop = abs(np.dot(obj, dk))<eps
    if verbose:
        print(f"(step=2, k={k}) dk: {dk}")
    return dk, stop

# %% [markdown]
# ## Paso 3

# %%
def step3(f, xk, dk, A2, b2, eps, N=10**2, sgm=0.1, verbose=False, k=-1):
    """
    Funcion que resuelve el problema lineal (Dk)
    definido por:
    (L) |  min <obj, d>
         |  s.a A1d <= 0
         |       Ed  = 0
    con dk la solucion optima.     
         
    Parametros
    ----------
    f : function
        Funcion objetivo
    xk : np.array (n, 1)
        Punto actual
    dk : np.array (n, 1)
        Direccion de descenso
    A2 : np.array (m_A2, n)
        Coef. de las restr. de desigualdad in-activas
    b2 : np.array (m_A2, 1)
        Lado derecho de las restr. de desigualdad activas
    eps : float
        Tolerancia para chequear que lmbdk sea pequeño
    N : int
        Tamaño de la discretizacion equiespaciada del intervalor 
        [0, bar_lmbdk]
    sgm : float en (0, 1)
        Pendiente del paso de armijo
    """
    # Lambda maximo
    dom = A2@dk>0
    bar_lmbdk = np.min((b2-A2@xk)[dom]/(A2@dk)[dom]) if np.sum(dom) != 0 else float("inf")

    # Paso de armijo
    ## Discretizacion del intervalo [0, bar_lmbdk]
    t = np.linspace(0, np.min([bar_lmbdk, 1]), N)
    h = 1/(N-1)
    ## Gradiente de phi en cero
    d_phi_0 = nd.Gradient(lambda t: f( xk + dk*t ))([0])
    ## lmbdk optimo
    dom = np.where(f( (xk + dk * t[:, None]).T ) <= f(xk) + sgm*d_phi_0*t)[0]
    ix_max = np.max(dom)
    lmbdk = ix_max * h * bar_lmbdk
    
    # Nuevo paso
    xk1 = xk + lmbdk * dk
    stop = lmbdk<eps
    if verbose:
        print(f"(step=3, k={k}) bar_lmbdk: {bar_lmbdk}")
        print(f"(step=3, k={k}) lmbdk: {lmbdk}")
    return xk1, stop

# %% [markdown]
# phi(t) <= phi(0) + sgm * phi'(0) * t

# %% [markdown]
# ## Clase Zoutendijk

# %%
class Zoutendijk(object):
    
    def __init__(self, fun: str, const: list):
        self.fun = fun
        self.const = const
        
        self.set_vars()
        self.set_f()
        self.set_A_b_E_e()
        print(f"""-------------- Model Size --------------
   Variables    :  {self.n}
   Constraints  :  {self.m}
   Eq. consts.  :  {self.m_E}
   Ineq. consts.:  {self.m_A}
 ------------------------------------------""")
    
    def set_vars(self):
        self.vars = set(re.findall("x\d", self.fun))
        for c in self.const:
            self.vars = self.vars.union(set(re.findall("x\d", c)))   
        self.vars = sorted(list(self.vars))
        self.dic_vars = {var: f"x[{k}]" for k, var in enumerate(self.vars)}
    
    def set_f(self):
        self.rename_fun = self.fun
        for k, v in self.dic_vars.items():
            self.rename_fun = self.rename_fun.replace(k, v)
    
    def set_A_b_E_e(self):
        self.n = len(self.dic_vars)
        self.m = len(self.const)
        self.m_A = sum(int("<" in c or ">" in c) for c in self.const)
        self.m_E = self.m-self.m_A

        self.A = None
        self.E = None

        self.b = None
        self.e = None

        if self.m_A:
            self.A = np.zeros((self.m_A, self.n))
            self.b = np.zeros(self.m_A)
        if self.m_E:
            self.E = np.zeros((self.m_E, self.n))
            self.e = np.zeros(self.m_E)

        i_A = 0
        i_E = 0
        for c in self.const:
            if "<" in c or ">" in c:
                sgn = 1 if "<" in c else -1
                left, right = c.split("<=") if sgn>0 else c.split(">=")
                self.b[i_A] = sgn*float(right.strip())

                t_2 = ""
                t_1 = ""
                t = ""
                for t1 in left.strip().split():
                    if t1 in self.dic_vars.keys():
                        v = self.dic_vars[t1]
                        j = int(re.findall("\d", v)[0])

                        if t_2 == t_1 == t == "":
                            self.A[i_A, j] = sgn
                        elif t_2 == t_1 == "" and t == "-":
                            self.A[i_A, j] = sgn*(-1)
                        elif t_2 in ["", "+"] and t == "*":
                            self.A[i_A, j] = sgn*float(t_1)
                        elif t_2 == "-" and t == "*":
                            self.A[i_A, j] = sgn*float(t_1)*(-1)
                        elif t_1 in self.dic_vars.keys() and t == "+":
                            self.A[i_A, j] = sgn
                        elif t_1 in self.dic_vars.keys() and t == "-":
                            self.A[i_A, j] = sgn*(-1)
                    t_2 = t_1
                    t_1 = t
                    t = t1
                i_A+=1
            else:
                left, right = c.split("=")
                self.e[i_E] = float(right.strip())

                t_2 = ""
                t_1 = ""
                t = ""
                for t1 in left.strip().split():
                    if t1 in self.dic_vars.keys():
                        v = self.dic_vars[t1]
                        j = int(re.findall("\d", v)[0])

                        if t_2 == t_1 == t == "":
                            self.E[i_E, j] = 1
                        elif t_2 == t_1 == "" and t == "-":
                            self.E[i_E, j] = -1
                        elif t_2 in ["", "+"] and t == "*":
                            self.E[i_E, j] = float(t_1)
                        elif t_2 == "-" and t == "*":
                            self.E[i_E, j] = float(t_1)*(-1)
                        elif t_1 in self.dic_vars.keys() and t == "+":
                            self.E[i_E, j] = 1
                        elif t_1 in self.dic_vars.keys() and t == "-":
                            self.E[i_E, j] = -1
                    t_2 = t_1
                    t_1 = t
                    t = t1
                i_E+=1
                
    def f(self, x):
        return eval(self.rename_fun)
                
    def solve(self, x0, eps=1e-6, N=10**2, sgm=0.5, verbose=True):
        start=time.time()
        # Step 0: Inicializar
        k = 0
        xk = x0
        grad = nd.Gradient(self.f)
        # Step 0: Check factibilidad
        feasible = step0(xk, self.A, self.b, self.E, self.e)
        stop = not feasible
        # Step 0: Imprimir estado
        f_xk = self.f(xk)
        if verbose:
            print(f"(step=0, k={k}) Factible: {feasible}")
            print(f"(step=0, k={k}) xk: {xk}")
            print(f"(step=0, k={k}) f(xk): {f_xk}\n")
        self.list_xk = [xk]
        self.list_f_xk = [f_xk]   
        self.list_feasible = [feasible]
        while not stop:
            # Step 1: Descomposicion [A1, A2]
            A1, A2, b1, b2 = step1(xk, self.A, self.b, verbose=verbose, k=k)
            # Step 2: Resolver problema lineal (Dk)
            obj = grad(xk)
            dk, stop_grad = step2(obj, A1, self.E, eps, verbose=verbose, k=k)
            stop = stop_grad
            if not stop:
                # Step 3: Resolver problema (L)
                xk1, stop_lambda = step3(self.f, xk, dk, A2, b2, eps=eps, N=N, sgm=sgm, verbose=verbose, k=k)
                xk = xk1
                feasible = step0(xk, self.A, self.b, self.E, self.e)
                stop = (not feasible) or stop_lambda
                # Step 3: Imprimir estado
                f_xk = self.f(xk)
                if verbose:
                    print(f"(step=3, k={k}) Factible: {feasible}")
                    print(f"(step=3, k={k}) xk: {xk}")
                    print(f"(step=3, k={k}) f(xk): {f_xk}\n")
                k+=1
                self.list_xk.append(xk)
                self.list_f_xk.append(f_xk)
                self.list_feasible.append(feasible)
        if k>0:
            print(f""" ---------------------------------------------------
 Solver         :  Zoutendijk (Simplex/Armijo)
 Solution time  :  {time.time()-start:.2f} ms
 Objective      :  {self.list_f_xk[-1]: .4f}
 Stop criterion :  {"f(xk) * dk < eps" if stop_grad else "lmbdk < eps" if stop_lambda else "Unfeasible" if not feasible else "?"}
 {"Successful solution" if feasible else "?"}
 ---------------------------------------------------""")
        if k==0:
            print(f""" ---------------------------------------------------
 Solver         :  Zoutendijk (Simplex/Armijo)
 Objective      :  {self.list_f_xk[-1]: .4f}
 Start point    :  {"Unfeasible" if not feasible else "?"}
 ---------------------------------------------------""")
                
    def report(self, feasible=False):
        df = pd.DataFrame(self.list_xk, columns=self.dic_vars.keys(), index=pd.Series(range(len(self.list_xk)), name="Iter. k"))
        df["f(xk)"] = self.list_f_xk
        if feasible:
            df["Factible"] = self.list_feasible
        return df

# %% [markdown]
# ## Problema 1
#
# $$(P_1) \quad \begin{cases} \min &8(x_1-6)^2+(x_2-2)^4 \\
# s.a. &-x_1+2x_2 \leq 4 \\
# &3x_1+2x_2 \leq 12 \\
# &x_i \geq 0, \quad i=1,2 \\
# \end{cases}$$

# %%
# %%time
# Inicializar datos del problema
problem_1 = Zoutendijk(
    fun="8 * ( x1 - 6 ) ** 2 + ( x2 - 2 ) ** 4", 
    const=[
        "- x1 + 2 * x2 <= 4",
        "3 * x1 + 2 * x2 <= 12",
        "x1 >= 0",
        "x2 >= 0"
    ]
)
# Resolver problema
problem_1.solve(
    x0=[0, 2], 
    eps=1e-6, 
    N=10**4, 
    sgm=0.6, 
    verbose=False
)
# Reportar resultados
problem_1.report(feasible=True)
# Out:
#  4
#  12
#  0
#  0
# -------------- Model Size --------------
#    Variables    :  2
#    Constraints  :  4
#    Eq. consts.  :  0
#    Ineq. consts.:  4
#  ------------------------------------------
#  ---------------------------------------------------
#  Solver         :  Zoutendijk (Simplex/Armijo)
#  Solution time  :  0.12 ms
#  Objective      :   46.9029
#  Stop criterion :  lmbdk < eps
#  Successful solution
#  ---------------------------------------------------
# Wall time: 116 ms
#                x1        x2       f(xk)  Factible
# Iter. k
# 0        0.000000  2.000000  288.000000      True
# 1        2.000000  3.000000  129.000000      True
# 2        4.000000  0.000000   48.000000      True
# 3        3.675368  0.486949   48.472334      True
# 4        3.830882  0.253677   46.940912      True
# 5        3.853022  0.220467   46.904344      True
# 6        3.857255  0.214117   46.902970      True
# 7        3.858097  0.212854   46.902915      True
# 8        3.858268  0.212598   46.902912      True
# 9        3.858296  0.212556   46.902912      True
# 10       3.858310  0.212535   46.902912      True
# 11       3.858310  0.212535   46.902912      True

# %% [markdown]
# https://www.wolframalpha.com/input?i=minimize+8%28x+%E2%88%92+6%29%5E2+%2B+%28y+%E2%88%92+2%29%5E4+subject+to+%E2%88%92x+%2B+2y+%3C%3D+4%2C++3x+%2B+2y+%3C%3D+12%2C+x+%3E%3D+0%2C+y+%3E%3D0

# %% [markdown]
# ## Problema 2
#
# $$(P_2) \quad \begin{cases} \min &x_1^4-2x_2^2+10x_1x_2^2+x_4^2 \\
# s.a. &x_1+x_2-x_3 = 1 \\
# &x_1+x_4 = 4 \\
# &x_1-x_2=0 \\
# &x_i \geq 0, \quad i=1,2 \\
# \end{cases}$$

# %%
# %%time
# Inicializar datos del problema
problem_2 = Zoutendijk(
    fun="x1 ** 4 - 2 * x2 ** 2 + 10 * x1 * ( x2 ** 2 ) + x4 ** 2", 
    const=[
        "x1 + x2 - x3 = 1",
        "x1 + x4 = 4",
        "x1 - x2 = 0",
        "x1 >= 0",
        "x2 >= 0",
        "x3 >= 0",
        "x4 >= 0"
    ]
)
# Resolver problema
problem_2.solve(
    x0=[2, 2, 3, 2], 
    eps=1e-6, 
    N=10**4, 
    sgm=0.6, 
    verbose=False
)
# Reportar resultados
problem_2.report(feasible=True)
# Out:
#  0
#  0
#  0
#  0
# -------------- Model Size --------------
#    Variables    :  4
#    Constraints  :  7
#    Eq. consts.  :  3
#    Ineq. consts.:  4
#  ------------------------------------------
#  ---------------------------------------------------
#  Solver         :  Zoutendijk (Simplex/Armijo)
#  Solution time  :  0.16 ms
#  Objective      :   13.0468
#  Stop criterion :  lmbdk < eps
#  Successful solution
#  ---------------------------------------------------
# Wall time: 169 ms
#                x1        x2        x3        x4      f(xk)  Factible
# Iter. k
# 0        2.000000  2.000000  3.000000  2.000000  92.000000      True
# 1        0.500000  0.500000  0.000000  3.500000  13.062500      True
# 2        0.677118  0.677118  0.354235  3.322882  13.439288      True
# 3        0.568038  0.568038  0.136075  3.431962  13.070015      True
# 4        0.539051  0.539051  0.078102  3.460949  13.047803      True
# 5        0.532740  0.532740  0.065479  3.467260  13.046797      True
# 6        0.531453  0.531453  0.062905  3.468547  13.046755      True
# 7        0.531195  0.531195  0.062390  3.468805  13.046754      True
# 8        0.531145  0.531145  0.062290  3.468855  13.046754      True
# 9        0.531132  0.531132  0.062265  3.468868  13.046754      True
# 10       0.531132  0.531132  0.062265  3.468868  13.046754      True

# %% [markdown]
# https://www.wolframalpha.com/input?i=minimize+x%5E4+-+2*y%5E2%2B10*x*y%5E2%2Bw%5E2%2B0.0000001*z+subject+to+x+%2B+y-+z%3D+1%2C+x%2B+w%3D+4%2C+x-+y%3D+0%2C+x%3E%3D0%2C+y%3E%3D0%2C+z%3E%3D0%2C+w%3E%3D0

# %% [markdown]
# BONUS

# %%
# %%time
# Inicializar datos del problema
problem_3 = Zoutendijk(
    fun="( 1 - x1 ) ** 2 + 100 * ( x2 - x1 ** 2) ** 2", 
    const=[
        "x1 <= 5",
        "x1 >= -5",
        "x2 <= 5",
        "x2 >= -5"
    ]
)
# Resolver problema
problem_3.solve(
    x0=[2, 2], 
    eps=1e-9, 
    N=10**4, 
    sgm=0.1, 
    verbose=True
)
# Reportar resultados
problem_3.report(feasible=True)
# Out:
# -------------- Model Size --------------
#    Variables    :  2
#    Constraints  :  4
#    Eq. consts.  :  0
#    Ineq. consts.:  4
#  ------------------------------------------
# (step=0, k=0) Factible: True
# (step=0, k=0) xk: [2, 2]
# (step=0, k=0) f(xk): 401
#
# (step=1, k=0) A1.index: [False False False False]
# (step=1, k=0) A2.index: [ True  True  True  True]
# (step=2, k=0) dk: [-1.  1.]
# (step=3, k=0) bar_lmbdk: 3.0
# (step=3, k=0) lmbdk: 2.5436543654365438
# (step=3, k=0) Factible: True
# (step=3, k=0) xk: [-0.54365437  4.54365437]
# (step=3, k=0) f(xk): 1807.013383892143
#
# (step=1, k=1) A1.index: [False False False False]
# (step=1, k=1) A2.index: [ True  True  True  True]
# (step=2, k=1) dk: [-1. -1.]
# (step=3, k=1) bar_lmbdk: 4.456345634563457
# (step=3, k=1) lmbdk: 4.456345634563457
# (step=3, k=1) Factible: True
# (step=3, k=1) xk: [-5.          0.08730873]
# (step=3, k=1) f(xk): 62100.21862708323
#
# (step=1, k=2) A1.index: [False  True False False]
# (step=1, k=2) A2.index: [ True False  True  True]
# (step=2, k=2) dk: [1. 1.]
# (step=3, k=2) bar_lmbdk: 4.912691269126913
# (step=3, k=2) lmbdk: 4.912691269126913
# (step=3, k=2) Factible: True
# (step=3, k=2) xk: [-0.08730873  5.        ]
# (step=3, k=2) f(xk): 2493.565236519634
#
# (step=1, k=3) A1.index: [False False  True False]
# (step=1, k=3) A2.index: [ True  True False  True]
# (step=2, k=3) dk: [-1. -1.]
# (step=3, k=3) bar_lmbdk: 4.912691269126913
# (step=3, k=3) lmbdk: 4.912691269126913
# (step=3, k=3) Factible: True
# (step=3, k=3) xk: [-5.          0.08730873]
# (step=3, k=3) f(xk): 62100.21862708323
#
# (step=1, k=4) A1.index: [False  True False False]
# (step=1, k=4) A2.index: [ True False  True  True]
# (step=2, k=4) dk: [1. 1.]
# (step=3, k=4) bar_lmbdk: 4.912691269126913
# (step=3, k=4) lmbdk: 4.912691269126913
# (step=3, k=4) Factible: True
# (step=3, k=4) xk: [-0.08730873  5.        ]
# (step=3, k=4) f(xk): 2493.565236519634
#
# (step=1, k=5) A1.index: [False False  True False]
# (step=1, k=5) A2.index: [ True  True False  True]
# (step=2, k=5) dk: [-1. -1.]
# (step=3, k=5) bar_lmbdk: 4.912691269126913
# (step=3, k=5) lmbdk: 4.912691269126913
# (step=3, k=5) Factible: True
# (step=3, k=5) xk: [-5.          0.08730873]
# (step=3, k=5) f(xk): 62100.21862708323
#
# (step=1, k=6) A1.index: [False  True False False]
# (step=1, k=6) A2.index: [ True False  True  True]
# (step=2, k=6) dk: [1. 1.]
# (step=3, k=6) bar_lmbdk: 4.912691269126913
# (step=3, k=6) lmbdk: 4.912691269126913
# (step=3, k=6) Factible: True
# (step=3, k=6) xk: [-0.08730873  5.        ]
# (step=3, k=6) f(xk): 2493.565236519634
#
# (step=1, k=7) A1.index: [False False  True False]
# (step=1, k=7) A2.index: [ True  True False  True]
# (step=2, k=7) dk: [-1. -1.]
# (step=3, k=7) bar_lmbdk: 4.912691269126913
# (step=3, k=7) lmbdk: 4.912691269126913
# (step=3, k=7) Factible: True
# (step=3, k=7) xk: [-5.          0.08730873]
# (step=3, k=7) f(xk): 62100.21862708323
#
# (step=1, k=8) A1.index: [False  True False False]
# (step=1, k=8) A2.index: [ True False  True  True]
# (step=2, k=8) dk: [1. 1.]
# (step=3, k=8) bar_lmbdk: 4.912691269126913
# (step=3, k=8) lmbdk: 4.912691269126913
# (step=3, k=8) Factible: True
# (step=3, k=8) xk: [-0.08730873  5.        ]
# (step=3, k=8) f(xk): 2493.565236519634
#
# (step=1, k=9) A1.index: [False False  True False]
# (step=1, k=9) A2.index: [ True  True False  True]
# (step=2, k=9) dk: [-1. -1.]
# (step=3, k=9) bar_lmbdk: 4.912691269126913
# (step=3, k=9) lmbdk: 4.912691269126913
# (step=3, k=9) Factible: True
# (step=3, k=9) xk: [-5.          0.08730873]
# (step=3, k=9) f(xk): 62100.21862708323
#
# (step=1, k=10) A1.index: [False  True False False]
# (step=1, k=10) A2.index: [ True False  True  True]
# (step=2, k=10) dk: [1. 1.]
# (step=3, k=10) bar_lmbdk: 4.912691269126913
# (step=3, k=10) lmbdk: 4.912691269126913
# (step=3, k=10) Factible: True
# (step=3, k=10) xk: [-0.08730873  5.        ]
# (step=3, k=10) f(xk): 2493.565236519634
#
# (step=1, k=11) A1.index: [False False  True False]
# (step=1, k=11) A2.index: [ True  True False  True]
# (step=2, k=11) dk: [-1. -1.]
# (step=3, k=11) bar_lmbdk: 4.912691269126913
# (step=3, k=11) lmbdk: 4.912691269126913
# (step=3, k=11) Factible: True
# (step=3, k=11) xk: [-5.          0.08730873]
# (step=3, k=11) f(xk): 62100.21862708323
#
# (step=1, k=12) A1.index: [False  True False False]
# (step=1, k=12) A2.index: [ True False  True  True]
# (step=2, k=12) dk: [1. 1.]
# (step=3, k=12) bar_lmbdk: 4.912691269126913
# (step=3, k=12) lmbdk: 4.912691269126913
# (step=3, k=12) Factible: True
# (step=3, k=12) xk: [-0.08730873  5.        ]
# (step=3, k=12) f(xk): 2493.565236519634
#
# (step=1, k=13) A1.index: [False False  True False]
# (step=1, k=13) A2.index: [ True  True False  True]
# (step=2, k=13) dk: [-1. -1.]
# (step=3, k=13) bar_lmbdk: 4.912691269126913
# (step=3, k=13) lmbdk: 4.912691269126913
# (step=3, k=13) Factible: True
# (step=3, k=13) xk: [-5.          0.08730873]
# (step=3, k=13) f(xk): 62100.21862708323
#
# (step=1, k=14) A1.index: [False  True False False]
# (step=1, k=14) A2.index: [ True False  True  True]
# (step=2, k=14) dk: [1. 1.]
# (step=3, k=14) bar_lmbdk: 4.912691269126913
# (step=3, k=14) lmbdk: 4.912691269126913
# (step=3, k=14) Factible: True
# (step=3, k=14) xk: [-0.08730873  5.        ]
# (step=3, k=14) f(xk): 2493.565236519634
#
# (step=1, k=15) A1.index: [False False  True False]
# (step=1, k=15) A2.index: [ True  True False  True]
# (step=2, k=15) dk: [-1. -1.]
# (step=3, k=15) bar_lmbdk: 4.912691269126913
# (step=3, k=15) lmbdk: 4.912691269126913
# (step=3, k=15) Factible: True
# (step=3, k=15) xk: [-5.          0.08730873]
# (step=3, k=15) f(xk): 62100.21862708323
#
# (step=1, k=16) A1.index: [False  True False False]
# (step=1, k=16) A2.index: [ True False  True  True]
# (step=2, k=16) dk: [1. 1.]
# (step=3, k=16) bar_lmbdk: 4.912691269126913
# (step=3, k=16) lmbdk: 4.912691269126913
# (step=3, k=16) Factible: True
# (step=3, k=16) xk: [-0.08730873  5.        ]
# (step=3, k=16) f(xk): 2493.565236519634
#
# (step=1, k=17) A1.index: [False False  True False]
# (step=1, k=17) A2.index: [ True  True False  True]
# (step=2, k=17) dk: [-1. -1.]
# (step=3, k=17) bar_lmbdk: 4.912691269126913
# (step=3, k=17) lmbdk: 4.912691269126913
# (step=3, k=17) Factible: True
# (step=3, k=17) xk: [-5.          0.08730873]
# (step=3, k=17) f(xk): 62100.21862708323
#
# (step=1, k=18) A1.index: [False  True False False]
# (step=1, k=18) A2.index: [ True False  True  True]
# (step=2, k=18) dk: [1. 1.]
# (step=3, k=18) bar_lmbdk: 4.912691269126913
# (step=3, k=18) lmbdk: 4.912691269126913
# (step=3, k=18) Factible: True
# (step=3, k=18) xk: [-0.08730873  5.        ]
# (step=3, k=18) f(xk): 2493.565236519634
#
# (step=1, k=19) A1.index: [False False  True False]
# (step=1, k=19) A2.index: [ True  True False  True]
# (step=2, k=19) dk: [-1. -1.]
# (step=3, k=19) bar_lmbdk: 4.912691269126913
# (step=3, k=19) lmbdk: 4.912691269126913
# (step=3, k=19) Factible: True
# (step=3, k=19) xk: [-5.          0.08730873]
# (step=3, k=19) f(xk): 62100.21862708323
#
# (step=1, k=20) A1.index: [False  True False False]
# (step=1, k=20) A2.index: [ True False  True  True]
# (step=2, k=20) dk: [1. 1.]
# (step=3, k=20) bar_lmbdk: 4.912691269126913
# (step=3, k=20) lmbdk: 4.912691269126913
# (step=3, k=20) Factible: True
# (step=3, k=20) xk: [-0.08730873  5.        ]
# (step=3, k=20) f(xk): 2493.565236519634
#
# (step=1, k=21) A1.index: [False False  True False]
# (step=1, k=21) A2.index: [ True  True False  True]
# (step=2, k=21) dk: [-1. -1.]
# (step=3, k=21) bar_lmbdk: 4.912691269126913
# (step=3, k=21) lmbdk: 4.912691269126913
# (step=3, k=21) Factible: True
# (step=3, k=21) xk: [-5.          0.08730873]
# (step=3, k=21) f(xk): 62100.21862708323
#
# (step=1, k=22) A1.index: [False  True False False]
# (step=1, k=22) A2.index: [ True False  True  True]
# (step=2, k=22) dk: [1. 1.]
# (step=3, k=22) bar_lmbdk: 4.912691269126913
# (step=3, k=22) lmbdk: 4.912691269126913
# (step=3, k=22) Factible: True
# (step=3, k=22) xk: [-0.08730873  5.        ]
# (step=3, k=22) f(xk): 2493.565236519634
#
# (step=1, k=23) A1.index: [False False  True False]
# (step=1, k=23) A2.index: [ True  True False  True]
# (step=2, k=23) dk: [-1. -1.]
# (step=3, k=23) bar_lmbdk: 4.912691269126913
# (step=3, k=23) lmbdk: 4.912691269126913
# (step=3, k=23) Factible: True
# (step=3, k=23) xk: [-5.          0.08730873]
# (step=3, k=23) f(xk): 62100.21862708323
#
# (step=1, k=24) A1.index: [False  True False False]
# (step=1, k=24) A2.index: [ True False  True  True]
# (step=2, k=24) dk: [1. 1.]
# (step=3, k=24) bar_lmbdk: 4.912691269126913
# (step=3, k=24) lmbdk: 4.912691269126913
# (step=3, k=24) Factible: True
# (step=3, k=24) xk: [-0.08730873  5.        ]
# (step=3, k=24) f(xk): 2493.565236519634
#
# (step=1, k=25) A1.index: [False False  True False]
# (step=1, k=25) A2.index: [ True  True False  True]
# (step=2, k=25) dk: [-1. -1.]
# (step=3, k=25) bar_lmbdk: 4.912691269126913
# (step=3, k=25) lmbdk: 4.912691269126913
# (step=3, k=25) Factible: True
# (step=3, k=25) xk: [-5.          0.08730873]
# (step=3, k=25) f(xk): 62100.21862708323
#
# (step=1, k=26) A1.index: [False  True False False]
# (step=1, k=26) A2.index: [ True False  True  True]
# (step=2, k=26) dk: [1. 1.]
# (step=3, k=26) bar_lmbdk: 4.912691269126913
# (step=3, k=26) lmbdk: 4.912691269126913
# (step=3, k=26) Factible: True
# (step=3, k=26) xk: [-0.08730873  5.        ]
# (step=3, k=26) f(xk): 2493.565236519634
#
# (step=1, k=27) A1.index: [False False  True False]
# (step=1, k=27) A2.index: [ True  True False  True]
# (step=2, k=27) dk: [-1. -1.]
# (step=3, k=27) bar_lmbdk: 4.912691269126913
# (step=3, k=27) lmbdk: 4.912691269126913
# (step=3, k=27) Factible: True
# (step=3, k=27) xk: [-5.          0.08730873]
# (step=3, k=27) f(xk): 62100.21862708323
#
# (step=1, k=28) A1.index: [False  True False False]
# (step=1, k=28) A2.index: [ True False  True  True]
# (step=2, k=28) dk: [1. 1.]
# (step=3, k=28) bar_lmbdk: 4.912691269126913
# (step=3, k=28) lmbdk: 4.912691269126913
# (step=3, k=28) Factible: True
# (step=3, k=28) xk: [-0.08730873  5.        ]
# (step=3, k=28) f(xk): 2493.565236519634
#
# (step=1, k=29) A1.index: [False False  True False]
# (step=1, k=29) A2.index: [ True  True False  True]
# (step=2, k=29) dk: [-1. -1.]
# (step=3, k=29) bar_lmbdk: 4.912691269126913
# (step=3, k=29) lmbdk: 4.912691269126913
# (step=3, k=29) Factible: True
# (step=3, k=29) xk: [-5.          0.08730873]
# (step=3, k=29) f(xk): 62100.21862708323
#
# (step=1, k=30) A1.index: [False  True False False]
# (step=1, k=30) A2.index: [ True False  True  True]
# (step=2, k=30) dk: [1. 1.]
# (step=3, k=30) bar_lmbdk: 4.912691269126913
# (step=3, k=30) lmbdk: 4.912691269126913
# (step=3, k=30) Factible: True
# (step=3, k=30) xk: [-0.08730873  5.        ]
# (step=3, k=30) f(xk): 2493.565236519634
#
# (step=1, k=31) A1.index: [False False  True False]
# (step=1, k=31) A2.index: [ True  True False  True]
# (step=2, k=31) dk: [-1. -1.]
# (step=3, k=31) bar_lmbdk: 4.912691269126913
# (step=3, k=31) lmbdk: 4.912691269126913
# (step=3, k=31) Factible: True
# (step=3, k=31) xk: [-5.          0.08730873]
# (step=3, k=31) f(xk): 62100.21862708323
#
# (step=1, k=32) A1.index: [False  True False False]
# (step=1, k=32) A2.index: [ True False  True  True]
# (step=2, k=32) dk: [1. 1.]
# (step=3, k=32) bar_lmbdk: 4.912691269126913
# (step=3, k=32) lmbdk: 4.912691269126913
# (step=3, k=32) Factible: True
# (step=3, k=32) xk: [-0.08730873  5.        ]
# (step=3, k=32) f(xk): 2493.565236519634
# (step=1, k=33) A1.index: [False False  True False]
# (step=1, k=33) A2.index: [ True  True False  True]
# (step=2, k=33) dk: [-1. -1.]
# (step=3, k=33) bar_lmbdk: 4.912691269126913
# (step=3, k=33) lmbdk: 4.912691269126913
# (step=3, k=33) Factible: True
# (step=3, k=33) xk: [-5.          0.08730873]
# (step=3, k=33) f(xk): 62100.21862708323
#
# (step=1, k=34) A1.index: [False  True False False]
# (step=1, k=34) A2.index: [ True False  True  True]
# (step=2, k=34) dk: [1. 1.]
# (step=3, k=34) bar_lmbdk: 4.912691269126913
# (step=3, k=34) lmbdk: 4.912691269126913
# (step=3, k=34) Factible: True
# (step=3, k=34) xk: [-0.08730873  5.        ]
# (step=3, k=34) f(xk): 2493.565236519634
#
# (step=1, k=35) A1.index: [False False  True False]
# (step=1, k=35) A2.index: [ True  True False  True]
# (step=2, k=35) dk: [-1. -1.]
# (step=3, k=35) bar_lmbdk: 4.912691269126913
# (step=3, k=35) lmbdk: 4.912691269126913
# (step=3, k=35) Factible: True
# (step=3, k=35) xk: [-5.          0.08730873]
# (step=3, k=35) f(xk): 62100.21862708323
#
# (step=1, k=36) A1.index: [False  True False False]
# (step=1, k=36) A2.index: [ True False  True  True]
# (step=2, k=36) dk: [1. 1.]
# (step=3, k=36) bar_lmbdk: 4.912691269126913
# (step=3, k=36) lmbdk: 4.912691269126913
# (step=3, k=36) Factible: True
# (step=3, k=36) xk: [-0.08730873  5.        ]
# (step=3, k=36) f(xk): 2493.565236519634
#
# (step=1, k=37) A1.index: [False False  True False]
# (step=1, k=37) A2.index: [ True  True False  True]
# (step=2, k=37) dk: [-1. -1.]
# (step=3, k=37) bar_lmbdk: 4.912691269126913
# (step=3, k=37) lmbdk: 4.912691269126913
# (step=3, k=37) Factible: True
# (step=3, k=37) xk: [-5.          0.08730873]
# (step=3, k=37) f(xk): 62100.21862708323
#
# (step=1, k=38) A1.index: [False  True False False]
# (step=1, k=38) A2.index: [ True False  True  True]
# (step=2, k=38) dk: [1. 1.]
# (step=3, k=38) bar_lmbdk: 4.912691269126913
# (step=3, k=38) lmbdk: 4.912691269126913
# (step=3, k=38) Factible: True
# (step=3, k=38) xk: [-0.08730873  5.        ]
# (step=3, k=38) f(xk): 2493.565236519634
#
# (step=1, k=39) A1.index: [False False  True False]
# (step=1, k=39) A2.index: [ True  True False  True]
# (step=2, k=39) dk: [-1. -1.]
# (step=3, k=39) bar_lmbdk: 4.912691269126913
# (step=3, k=39) lmbdk: 4.912691269126913
# (step=3, k=39) Factible: True
# (step=3, k=39) xk: [-5.          0.08730873]
# (step=3, k=39) f(xk): 62100.21862708323
#
# (step=1, k=40) A1.index: [False  True False False]
# (step=1, k=40) A2.index: [ True False  True  True]
# (step=2, k=40) dk: [1. 1.]
# (step=3, k=40) bar_lmbdk: 4.912691269126913
# (step=3, k=40) lmbdk: 4.912691269126913
# (step=3, k=40) Factible: True
# (step=3, k=40) xk: [-0.08730873  5.        ]
# (step=3, k=40) f(xk): 2493.565236519634
#
# (step=1, k=41) A1.index: [False False  True False]
# (step=1, k=41) A2.index: [ True  True False  True]
# (step=2, k=41) dk: [-1. -1.]
# (step=3, k=41) bar_lmbdk: 4.912691269126913
# (step=3, k=41) lmbdk: 4.912691269126913
# (step=3, k=41) Factible: True
# (step=3, k=41) xk: [-5.          0.08730873]
# (step=3, k=41) f(xk): 62100.21862708323
#
# (step=1, k=42) A1.index: [False  True False False]
# (step=1, k=42) A2.index: [ True False  True  True]
# (step=2, k=42) dk: [1. 1.]
# (step=3, k=42) bar_lmbdk: 4.912691269126913
# (step=3, k=42) lmbdk: 4.912691269126913
# (step=3, k=42) Factible: True
# (step=3, k=42) xk: [-0.08730873  5.        ]
# (step=3, k=42) f(xk): 2493.565236519634
#
# (step=1, k=43) A1.index: [False False  True False]
# (step=1, k=43) A2.index: [ True  True False  True]
# (step=2, k=43) dk: [-1. -1.]
# (step=3, k=43) bar_lmbdk: 4.912691269126913
# (step=3, k=43) lmbdk: 4.912691269126913
# (step=3, k=43) Factible: True
# (step=3, k=43) xk: [-5.          0.08730873]
# (step=3, k=43) f(xk): 62100.21862708323
#
# (step=1, k=44) A1.index: [False  True False False]
# (step=1, k=44) A2.index: [ True False  True  True]
# (step=2, k=44) dk: [1. 1.]
# (step=3, k=44) bar_lmbdk: 4.912691269126913
# (step=3, k=44) lmbdk: 4.912691269126913
# (step=3, k=44) Factible: True
# (step=3, k=44) xk: [-0.08730873  5.        ]
# (step=3, k=44) f(xk): 2493.565236519634
#
# (step=1, k=45) A1.index: [False False  True False]
# (step=1, k=45) A2.index: [ True  True False  True]
# (step=2, k=45) dk: [-1. -1.]
# (step=3, k=45) bar_lmbdk: 4.912691269126913
# (step=3, k=45) lmbdk: 4.912691269126913
# (step=3, k=45) Factible: True
# (step=3, k=45) xk: [-5.          0.08730873]
# (step=3, k=45) f(xk): 62100.21862708323
#
# (step=1, k=46) A1.index: [False  True False False]
# (step=1, k=46) A2.index: [ True False  True  True]
# (step=2, k=46) dk: [1. 1.]
# (step=3, k=46) bar_lmbdk: 4.912691269126913
# (step=3, k=46) lmbdk: 4.912691269126913
# (step=3, k=46) Factible: True
# (step=3, k=46) xk: [-0.08730873  5.        ]
# (step=3, k=46) f(xk): 2493.565236519634
#
# (step=1, k=47) A1.index: [False False  True False]
# (step=1, k=47) A2.index: [ True  True False  True]
# (step=2, k=47) dk: [-1. -1.]
# (step=3, k=47) bar_lmbdk: 4.912691269126913
# (step=3, k=47) lmbdk: 4.912691269126913
# (step=3, k=47) Factible: True
# (step=3, k=47) xk: [-5.          0.08730873]
# (step=3, k=47) f(xk): 62100.21862708323
#
# (step=1, k=48) A1.index: [False  True False False]
# (step=1, k=48) A2.index: [ True False  True  True]
# (step=2, k=48) dk: [1. 1.]
# (step=3, k=48) bar_lmbdk: 4.912691269126913
# (step=3, k=48) lmbdk: 4.912691269126913
# (step=3, k=48) Factible: True
# (step=3, k=48) xk: [-0.08730873  5.        ]
# (step=3, k=48) f(xk): 2493.565236519634
#
# (step=1, k=49) A1.index: [False False  True False]
# (step=1, k=49) A2.index: [ True  True False  True]
# (step=2, k=49) dk: [-1. -1.]
# (step=3, k=49) bar_lmbdk: 4.912691269126913
# (step=3, k=49) lmbdk: 4.912691269126913
# (step=3, k=49) Factible: True
# (step=3, k=49) xk: [-5.          0.08730873]
# (step=3, k=49) f(xk): 62100.21862708323
#
# (step=1, k=50) A1.index: [False  True False False]
# (step=1, k=50) A2.index: [ True False  True  True]
# (step=2, k=50) dk: [1. 1.]
# (step=3, k=50) bar_lmbdk: 4.912691269126913
# (step=3, k=50) lmbdk: 4.912691269126913
# (step=3, k=50) Factible: True
# (step=3, k=50) xk: [-0.08730873  5.        ]
# (step=3, k=50) f(xk): 2493.565236519634
#
# (step=1, k=51) A1.index: [False False  True False]
# (step=1, k=51) A2.index: [ True  True False  True]
# (step=2, k=51) dk: [-1. -1.]
# (step=3, k=51) bar_lmbdk: 4.912691269126913
# (step=3, k=51) lmbdk: 4.912691269126913
# (step=3, k=51) Factible: True
# (step=3, k=51) xk: [-5.          0.08730873]
# (step=3, k=51) f(xk): 62100.21862708323
#
# (step=1, k=52) A1.index: [False  True False False]
# (step=1, k=52) A2.index: [ True False  True  True]
# (step=2, k=52) dk: [1. 1.]
# (step=3, k=52) bar_lmbdk: 4.912691269126913
# (step=3, k=52) lmbdk: 4.912691269126913
# (step=3, k=52) Factible: True
# (step=3, k=52) xk: [-0.08730873  5.        ]
# (step=3, k=52) f(xk): 2493.565236519634
#
# (step=1, k=53) A1.index: [False False  True False]
# (step=1, k=53) A2.index: [ True  True False  True]
# (step=2, k=53) dk: [-1. -1.]
# (step=3, k=53) bar_lmbdk: 4.912691269126913
# (step=3, k=53) lmbdk: 4.912691269126913
# (step=3, k=53) Factible: True
# (step=3, k=53) xk: [-5.          0.08730873]
# (step=3, k=53) f(xk): 62100.21862708323
#
# (step=1, k=54) A1.index: [False  True False False]
# (step=1, k=54) A2.index: [ True False  True  True]
# (step=2, k=54) dk: [1. 1.]
# (step=3, k=54) bar_lmbdk: 4.912691269126913
# (step=3, k=54) lmbdk: 4.912691269126913
# (step=3, k=54) Factible: True
# (step=3, k=54) xk: [-0.08730873  5.        ]
# (step=3, k=54) f(xk): 2493.565236519634
#
# (step=1, k=55) A1.index: [False False  True False]
# (step=1, k=55) A2.index: [ True  True False  True]
# (step=2, k=55) dk: [-1. -1.]
# (step=3, k=55) bar_lmbdk: 4.912691269126913
# (step=3, k=55) lmbdk: 4.912691269126913
# (step=3, k=55) Factible: True
# (step=3, k=55) xk: [-5.          0.08730873]
# (step=3, k=55) f(xk): 62100.21862708323
#
# (step=1, k=56) A1.index: [False  True False False]
# (step=1, k=56) A2.index: [ True False  True  True]
# (step=2, k=56) dk: [1. 1.]
# (step=3, k=56) bar_lmbdk: 4.912691269126913
# (step=3, k=56) lmbdk: 4.912691269126913
# (step=3, k=56) Factible: True
# (step=3, k=56) xk: [-0.08730873  5.        ]
# (step=3, k=56) f(xk): 2493.565236519634
#
# (step=1, k=57) A1.index: [False False  True False]
# (step=1, k=57) A2.index: [ True  True False  True]
# (step=2, k=57) dk: [-1. -1.]
# (step=3, k=57) bar_lmbdk: 4.912691269126913
# (step=3, k=57) lmbdk: 4.912691269126913
# (step=3, k=57) Factible: True
# (step=3, k=57) xk: [-5.          0.08730873]
# (step=3, k=57) f(xk): 62100.21862708323
#
# (step=1, k=58) A1.index: [False  True False False]
# (step=1, k=58) A2.index: [ True False  True  True]
# (step=2, k=58) dk: [1. 1.]
# (step=3, k=58) bar_lmbdk: 4.912691269126913
# (step=3, k=58) lmbdk: 4.912691269126913
# (step=3, k=58) Factible: True
# (step=3, k=58) xk: [-0.08730873  5.        ]
# (step=3, k=58) f(xk): 2493.565236519634
#
# (step=1, k=59) A1.index: [False False  True False]
# (step=1, k=59) A2.index: [ True  True False  True]
# (step=2, k=59) dk: [-1. -1.]
# (step=3, k=59) bar_lmbdk: 4.912691269126913
# (step=3, k=59) lmbdk: 4.912691269126913
# (step=3, k=59) Factible: True
# (step=3, k=59) xk: [-5.          0.08730873]
# (step=3, k=59) f(xk): 62100.21862708323
#
# (step=1, k=60) A1.index: [False  True False False]
# (step=1, k=60) A2.index: [ True False  True  True]
# (step=2, k=60) dk: [1. 1.]
# (step=3, k=60) bar_lmbdk: 4.912691269126913
# (step=3, k=60) lmbdk: 4.912691269126913
# (step=3, k=60) Factible: True
# (step=3, k=60) xk: [-0.08730873  5.        ]
# (step=3, k=60) f(xk): 2493.565236519634
#
# (step=1, k=61) A1.index: [False False  True False]
# (step=1, k=61) A2.index: [ True  True False  True]
# (step=2, k=61) dk: [-1. -1.]
# (step=3, k=61) bar_lmbdk: 4.912691269126913
# (step=3, k=61) lmbdk: 4.912691269126913
# (step=3, k=61) Factible: True
# (step=3, k=61) xk: [-5.          0.08730873]
# (step=3, k=61) f(xk): 62100.21862708323
#
# (step=1, k=62) A1.index: [False  True False False]
# (step=1, k=62) A2.index: [ True False  True  True]
# (step=2, k=62) dk: [1. 1.]
# (step=3, k=62) bar_lmbdk: 4.912691269126913
# (step=3, k=62) lmbdk: 4.912691269126913
# (step=3, k=62) Factible: True
# (step=3, k=62) xk: [-0.08730873  5.        ]
# (step=3, k=62) f(xk): 2493.565236519634
#
# (step=1, k=63) A1.index: [False False  True False]
# (step=1, k=63) A2.index: [ True  True False  True]
# (step=2, k=63) dk: [-1. -1.]
# (step=3, k=63) bar_lmbdk: 4.912691269126913
# (step=3, k=63) lmbdk: 4.912691269126913
# (step=3, k=63) Factible: True
# (step=3, k=63) xk: [-5.          0.08730873]
# (step=3, k=63) f(xk): 62100.21862708323
#
# (step=1, k=64) A1.index: [False  True False False]
# (step=1, k=64) A2.index: [ True False  True  True]
# (step=2, k=64) dk: [1. 1.]
# (step=3, k=64) bar_lmbdk: 4.912691269126913
# (step=3, k=64) lmbdk: 4.912691269126913
# (step=3, k=64) Factible: True
# (step=3, k=64) xk: [-0.08730873  5.        ]
# (step=3, k=64) f(xk): 2493.565236519634
#
# (step=1, k=65) A1.index: [False False  True False]
# (step=1, k=65) A2.index: [ True  True False  True]
# (step=2, k=65) dk: [-1. -1.]
# (step=3, k=65) bar_lmbdk: 4.912691269126913
# (step=3, k=65) lmbdk: 4.912691269126913
# (step=3, k=65) Factible: True
# (step=3, k=65) xk: [-5.          0.08730873]
# (step=3, k=65) f(xk): 62100.21862708323
#
# (step=1, k=66) A1.index: [False  True False False]
# (step=1, k=66) A2.index: [ True False  True  True]
# (step=2, k=66) dk: [1. 1.]
# (step=3, k=66) bar_lmbdk: 4.912691269126913
# (step=3, k=66) lmbdk: 4.912691269126913
# (step=3, k=66) Factible: True
# (step=3, k=66) xk: [-0.08730873  5.        ]
# (step=3, k=66) f(xk): 2493.565236519634
#
# (step=1, k=67) A1.index: [False False  True False]
# (step=1, k=67) A2.index: [ True  True False  True]
# (step=2, k=67) dk: [-1. -1.]
# (step=3, k=67) bar_lmbdk: 4.912691269126913
# (step=3, k=67) lmbdk: 4.912691269126913
# (step=3, k=67) Factible: True
# (step=3, k=67) xk: [-5.          0.08730873]
# (step=3, k=67) f(xk): 62100.21862708323
#
# (step=1, k=68) A1.index: [False  True False False]
# (step=1, k=68) A2.index: [ True False  True  True]
# (step=2, k=68) dk: [1. 1.]
# (step=3, k=68) bar_lmbdk: 4.912691269126913
# (step=3, k=68) lmbdk: 4.912691269126913
# (step=3, k=68) Factible: True
# (step=3, k=68) xk: [-0.08730873  5.        ]
# (step=3, k=68) f(xk): 2493.565236519634
#
# (step=1, k=69) A1.index: [False False  True False]
# (step=1, k=69) A2.index: [ True  True False  True]
# (step=2, k=69) dk: [-1. -1.]
# (step=3, k=69) bar_lmbdk: 4.912691269126913
# (step=3, k=69) lmbdk: 4.912691269126913
# (step=3, k=69) Factible: True
# (step=3, k=69) xk: [-5.          0.08730873]
# (step=3, k=69) f(xk): 62100.21862708323
#
# (step=1, k=70) A1.index: [False  True False False]
# (step=1, k=70) A2.index: [ True False  True  True]
# (step=2, k=70) dk: [1. 1.]
# (step=3, k=70) bar_lmbdk: 4.912691269126913
# (step=3, k=70) lmbdk: 4.912691269126913
# (step=3, k=70) Factible: True
# (step=3, k=70) xk: [-0.08730873  5.        ]
# (step=3, k=70) f(xk): 2493.565236519634
#
# (step=1, k=71) A1.index: [False False  True False]
# (step=1, k=71) A2.index: [ True  True False  True]
# (step=2, k=71) dk: [-1. -1.]
# (step=3, k=71) bar_lmbdk: 4.912691269126913
# (step=3, k=71) lmbdk: 4.912691269126913
# (step=3, k=71) Factible: True
# (step=3, k=71) xk: [-5.          0.08730873]
# (step=3, k=71) f(xk): 62100.21862708323
#
# (step=1, k=72) A1.index: [False  True False False]
# (step=1, k=72) A2.index: [ True False  True  True]
# (step=2, k=72) dk: [1. 1.]
# (step=3, k=72) bar_lmbdk: 4.912691269126913
# (step=3, k=72) lmbdk: 4.912691269126913
# (step=3, k=72) Factible: True
# (step=3, k=72) xk: [-0.08730873  5.        ]
# (step=3, k=72) f(xk): 2493.565236519634
#
# (step=1, k=73) A1.index: [False False  True False]
# (step=1, k=73) A2.index: [ True  True False  True]
# (step=2, k=73) dk: [-1. -1.]
# (step=3, k=73) bar_lmbdk: 4.912691269126913
# (step=3, k=73) lmbdk: 4.912691269126913
# (step=3, k=73) Factible: True
# (step=3, k=73) xk: [-5.          0.08730873]
# (step=3, k=73) f(xk): 62100.21862708323
#
# (step=1, k=74) A1.index: [False  True False False]
# (step=1, k=74) A2.index: [ True False  True  True]
# (step=2, k=74) dk: [1. 1.]
# (step=3, k=74) bar_lmbdk: 4.912691269126913
# (step=3, k=74) lmbdk: 4.912691269126913
# (step=3, k=74) Factible: True
# (step=3, k=74) xk: [-0.08730873  5.        ]
# (step=3, k=74) f(xk): 2493.565236519634
#
# (step=1, k=75) A1.index: [False False  True False]
# (step=1, k=75) A2.index: [ True  True False  True]
# (step=2, k=75) dk: [-1. -1.]
# (step=3, k=75) bar_lmbdk: 4.912691269126913
# (step=3, k=75) lmbdk: 4.912691269126913
# (step=3, k=75) Factible: True
# (step=3, k=75) xk: [-5.          0.08730873]
# (step=3, k=75) f(xk): 62100.21862708323
#
# (step=1, k=76) A1.index: [False  True False False]
# (step=1, k=76) A2.index: [ True False  True  True]
# (step=2, k=76) dk: [1. 1.]
# (step=3, k=76) bar_lmbdk: 4.912691269126913
# (step=3, k=76) lmbdk: 4.912691269126913
# (step=3, k=76) Factible: True
# (step=3, k=76) xk: [-0.08730873  5.        ]
# (step=3, k=76) f(xk): 2493.565236519634
#
# (step=1, k=77) A1.index: [False False  True False]
# (step=1, k=77) A2.index: [ True  True False  True]
# (step=2, k=77) dk: [-1. -1.]
# (step=3, k=77) bar_lmbdk: 4.912691269126913
# (step=3, k=77) lmbdk: 4.912691269126913
# (step=3, k=77) Factible: True
# (step=3, k=77) xk: [-5.          0.08730873]
# (step=3, k=77) f(xk): 62100.21862708323
#
# (step=1, k=78) A1.index: [False  True False False]
# (step=1, k=78) A2.index: [ True False  True  True]
# (step=2, k=78) dk: [1. 1.]
# (step=3, k=78) bar_lmbdk: 4.912691269126913
# (step=3, k=78) lmbdk: 4.912691269126913
# (step=3, k=78) Factible: True
# (step=3, k=78) xk: [-0.08730873  5.        ]
# (step=3, k=78) f(xk): 2493.565236519634
#
# (step=1, k=79) A1.index: [False False  True False]
# (step=1, k=79) A2.index: [ True  True False  True]
# (step=2, k=79) dk: [-1. -1.]
# (step=3, k=79) bar_lmbdk: 4.912691269126913
# (step=3, k=79) lmbdk: 4.912691269126913
# (step=3, k=79) Factible: True
# (step=3, k=79) xk: [-5.          0.08730873]
# (step=3, k=79) f(xk): 62100.21862708323
#
# (step=1, k=80) A1.index: [False  True False False]
# (step=1, k=80) A2.index: [ True False  True  True]
# (step=2, k=80) dk: [1. 1.]
# (step=3, k=80) bar_lmbdk: 4.912691269126913
# (step=3, k=80) lmbdk: 4.912691269126913
# (step=3, k=80) Factible: True
# (step=3, k=80) xk: [-0.08730873  5.        ]
# (step=3, k=80) f(xk): 2493.565236519634
#
# (step=1, k=81) A1.index: [False False  True False]
# (step=1, k=81) A2.index: [ True  True False  True]
# (step=2, k=81) dk: [-1. -1.]
# (step=3, k=81) bar_lmbdk: 4.912691269126913
# (step=3, k=81) lmbdk: 4.912691269126913
# (step=3, k=81) Factible: True
# (step=3, k=81) xk: [-5.          0.08730873]
# (step=3, k=81) f(xk): 62100.21862708323
#
# (step=1, k=82) A1.index: [False  True False False]
# (step=1, k=82) A2.index: [ True False  True  True]
# (step=2, k=82) dk: [1. 1.]
# (step=3, k=82) bar_lmbdk: 4.912691269126913
# (step=3, k=82) lmbdk: 4.912691269126913
# (step=3, k=82) Factible: True
# (step=3, k=82) xk: [-0.08730873  5.        ]
# (step=3, k=82) f(xk): 2493.565236519634
#
# (step=1, k=83) A1.index: [False False  True False]
# (step=1, k=83) A2.index: [ True  True False  True]
# (step=2, k=83) dk: [-1. -1.]
# (step=3, k=83) bar_lmbdk: 4.912691269126913
# (step=3, k=83) lmbdk: 4.912691269126913
# (step=3, k=83) Factible: True
# (step=3, k=83) xk: [-5.          0.08730873]
# (step=3, k=83) f(xk): 62100.21862708323
#
# (step=1, k=84) A1.index: [False  True False False]
# (step=1, k=84) A2.index: [ True False  True  True]
# (step=2, k=84) dk: [1. 1.]
# (step=3, k=84) bar_lmbdk: 4.912691269126913
# (step=3, k=84) lmbdk: 4.912691269126913
# (step=3, k=84) Factible: True
# (step=3, k=84) xk: [-0.08730873  5.        ]
# (step=3, k=84) f(xk): 2493.565236519634
#
# (step=1, k=85) A1.index: [False False  True False]
# (step=1, k=85) A2.index: [ True  True False  True]
# (step=2, k=85) dk: [-1. -1.]
# (step=3, k=85) bar_lmbdk: 4.912691269126913
# (step=3, k=85) lmbdk: 4.912691269126913
# (step=3, k=85) Factible: True
# (step=3, k=85) xk: [-5.          0.08730873]
# (step=3, k=85) f(xk): 62100.21862708323
#
# (step=1, k=86) A1.index: [False  True False False]
# (step=1, k=86) A2.index: [ True False  True  True]
# (step=2, k=86) dk: [1. 1.]
# (step=3, k=86) bar_lmbdk: 4.912691269126913
# (step=3, k=86) lmbdk: 4.912691269126913
# (step=3, k=86) Factible: True
# (step=3, k=86) xk: [-0.08730873  5.        ]
# (step=3, k=86) f(xk): 2493.565236519634
#
# (step=1, k=87) A1.index: [False False  True False]
# (step=1, k=87) A2.index: [ True  True False  True]
# (step=2, k=87) dk: [-1. -1.]
# (step=3, k=87) bar_lmbdk: 4.912691269126913
# (step=3, k=87) lmbdk: 4.912691269126913
# (step=3, k=87) Factible: True
# (step=3, k=87) xk: [-5.          0.08730873]
# (step=3, k=87) f(xk): 62100.21862708323
#
# (step=1, k=88) A1.index: [False  True False False]
# (step=1, k=88) A2.index: [ True False  True  True]
# (step=2, k=88) dk: [1. 1.]
# (step=3, k=88) bar_lmbdk: 4.912691269126913
# (step=3, k=88) lmbdk: 4.912691269126913
# (step=3, k=88) Factible: True
# (step=3, k=88) xk: [-0.08730873  5.        ]
# (step=3, k=88) f(xk): 2493.565236519634
#
# (step=1, k=89) A1.index: [False False  True False]
# (step=1, k=89) A2.index: [ True  True False  True]
# (step=2, k=89) dk: [-1. -1.]
# (step=3, k=89) bar_lmbdk: 4.912691269126913
# (step=3, k=89) lmbdk: 4.912691269126913
# (step=3, k=89) Factible: True
# (step=3, k=89) xk: [-5.          0.08730873]
# (step=3, k=89) f(xk): 62100.21862708323
#
# (step=1, k=90) A1.index: [False  True False False]
# (step=1, k=90) A2.index: [ True False  True  True]
# (step=2, k=90) dk: [1. 1.]
# (step=3, k=90) bar_lmbdk: 4.912691269126913
# (step=3, k=90) lmbdk: 4.912691269126913
# (step=3, k=90) Factible: True
# (step=3, k=90) xk: [-0.08730873  5.        ]
# (step=3, k=90) f(xk): 2493.565236519634
#
# (step=1, k=91) A1.index: [False False  True False]
# (step=1, k=91) A2.index: [ True  True False  True]
# (step=2, k=91) dk: [-1. -1.]
# (step=3, k=91) bar_lmbdk: 4.912691269126913
# (step=3, k=91) lmbdk: 4.912691269126913
# (step=3, k=91) Factible: True
# (step=3, k=91) xk: [-5.          0.08730873]
# (step=3, k=91) f(xk): 62100.21862708323
#
# (step=1, k=92) A1.index: [False  True False False]
# (step=1, k=92) A2.index: [ True False  True  True]
# (step=2, k=92) dk: [1. 1.]
# (step=3, k=92) bar_lmbdk: 4.912691269126913
# (step=3, k=92) lmbdk: 4.912691269126913
# (step=3, k=92) Factible: True
# (step=3, k=92) xk: [-0.08730873  5.        ]
# (step=3, k=92) f(xk): 2493.565236519634
#
# (step=1, k=93) A1.index: [False False  True False]
# (step=1, k=93) A2.index: [ True  True False  True]
# (step=2, k=93) dk: [-1. -1.]
# (step=3, k=93) bar_lmbdk: 4.912691269126913
# (step=3, k=93) lmbdk: 4.912691269126913
# (step=3, k=93) Factible: True
# (step=3, k=93) xk: [-5.          0.08730873]
# (step=3, k=93) f(xk): 62100.21862708323
#
# (step=1, k=94) A1.index: [False  True False False]
# (step=1, k=94) A2.index: [ True False  True  True]
# (step=2, k=94) dk: [1. 1.]
# (step=3, k=94) bar_lmbdk: 4.912691269126913
# (step=3, k=94) lmbdk: 4.912691269126913
# (step=3, k=94) Factible: True
# (step=3, k=94) xk: [-0.08730873  5.        ]
# (step=3, k=94) f(xk): 2493.565236519634
#
# (step=1, k=95) A1.index: [False False  True False]
# (step=1, k=95) A2.index: [ True  True False  True]
# (step=2, k=95) dk: [-1. -1.]
# (step=3, k=95) bar_lmbdk: 4.912691269126913
# (step=3, k=95) lmbdk: 4.912691269126913
# (step=3, k=95) Factible: True
# (step=3, k=95) xk: [-5.          0.08730873]
# (step=3, k=95) f(xk): 62100.21862708323
#
# (step=1, k=96) A1.index: [False  True False False]
# (step=1, k=96) A2.index: [ True False  True  True]
# (step=2, k=96) dk: [1. 1.]
# (step=3, k=96) bar_lmbdk: 4.912691269126913
# (step=3, k=96) lmbdk: 4.912691269126913
# (step=3, k=96) Factible: True
# (step=3, k=96) xk: [-0.08730873  5.        ]
# (step=3, k=96) f(xk): 2493.565236519634
#
# (step=1, k=97) A1.index: [False False  True False]
# (step=1, k=97) A2.index: [ True  True False  True]
# (step=2, k=97) dk: [-1. -1.]
# (step=3, k=97) bar_lmbdk: 4.912691269126913
# (step=3, k=97) lmbdk: 4.912691269126913
# (step=3, k=97) Factible: True
# (step=3, k=97) xk: [-5.          0.08730873]
# (step=3, k=97) f(xk): 62100.21862708323
#
# (step=1, k=98) A1.index: [False  True False False]
# (step=1, k=98) A2.index: [ True False  True  True]
# (step=2, k=98) dk: [1. 1.]
# (step=3, k=98) bar_lmbdk: 4.912691269126913
# (step=3, k=98) lmbdk: 4.912691269126913
# (step=3, k=98) Factible: True
# (step=3, k=98) xk: [-0.08730873  5.        ]
# (step=3, k=98) f(xk): 2493.565236519634
#
# (step=1, k=99) A1.index: [False False  True False]
# (step=1, k=99) A2.index: [ True  True False  True]
# (step=2, k=99) dk: [-1. -1.]
# (step=3, k=99) bar_lmbdk: 4.912691269126913
# (step=3, k=99) lmbdk: 4.912691269126913
# (step=3, k=99) Factible: True
# (step=3, k=99) xk: [-5.          0.08730873]
# (step=3, k=99) f(xk): 62100.21862708323
#
# (step=1, k=100) A1.index: [False  True False False]
# (step=1, k=100) A2.index: [ True False  True  True]
# (step=2, k=100) dk: [1. 1.]
# (step=3, k=100) bar_lmbdk: 4.912691269126913
# (step=3, k=100) lmbdk: 4.912691269126913
# (step=3, k=100) Factible: True
# (step=3, k=100) xk: [-0.08730873  5.        ]
# (step=3, k=100) f(xk): 2493.565236519634
#
# (step=1, k=101) A1.index: [False False  True False]
# (step=1, k=101) A2.index: [ True  True False  True]
# (step=2, k=101) dk: [-1. -1.]
# (step=3, k=101) bar_lmbdk: 4.912691269126913
# (step=3, k=101) lmbdk: 4.912691269126913
# (step=3, k=101) Factible: True
# (step=3, k=101) xk: [-5.          0.08730873]
# (step=3, k=101) f(xk): 62100.21862708323
#
# (step=1, k=102) A1.index: [False  True False False]
# (step=1, k=102) A2.index: [ True False  True  True]
# (step=2, k=102) dk: [1. 1.]
# (step=3, k=102) bar_lmbdk: 4.912691269126913
# (step=3, k=102) lmbdk: 4.912691269126913
# (step=3, k=102) Factible: True
# (step=3, k=102) xk: [-0.08730873  5.        ]
# (step=3, k=102) f(xk): 2493.565236519634
#
# (step=1, k=103) A1.index: [False False  True False]
# (step=1, k=103) A2.index: [ True  True False  True]
# (step=2, k=103) dk: [-1. -1.]
# (step=3, k=103) bar_lmbdk: 4.912691269126913
# (step=3, k=103) lmbdk: 4.912691269126913
# (step=3, k=103) Factible: True
# (step=3, k=103) xk: [-5.          0.08730873]
# (step=3, k=103) f(xk): 62100.21862708323
#
# (step=1, k=104) A1.index: [False  True False False]
# (step=1, k=104) A2.index: [ True False  True  True]
# (step=2, k=104) dk: [1. 1.]
# (step=3, k=104) bar_lmbdk: 4.912691269126913
# (step=3, k=104) lmbdk: 4.912691269126913
# (step=3, k=104) Factible: True
# (step=3, k=104) xk: [-0.08730873  5.        ]
# (step=3, k=104) f(xk): 2493.565236519634
#
# (step=1, k=105) A1.index: [False False  True False]
# (step=1, k=105) A2.index: [ True  True False  True]
# (step=2, k=105) dk: [-1. -1.]
# (step=3, k=105) bar_lmbdk: 4.912691269126913
# (step=3, k=105) lmbdk: 4.912691269126913
# (step=3, k=105) Factible: True
# (step=3, k=105) xk: [-5.          0.08730873]
# (step=3, k=105) f(xk): 62100.21862708323
#
# (step=1, k=106) A1.index: [False  True False False]
# (step=1, k=106) A2.index: [ True False  True  True]
# (step=2, k=106) dk: [1. 1.]
# (step=3, k=106) bar_lmbdk: 4.912691269126913
# (step=3, k=106) lmbdk: 4.912691269126913
# (step=3, k=106) Factible: True
# (step=3, k=106) xk: [-0.08730873  5.        ]
# (step=3, k=106) f(xk): 2493.565236519634
#
# (step=1, k=107) A1.index: [False False  True False]
# (step=1, k=107) A2.index: [ True  True False  True]
# (step=2, k=107) dk: [-1. -1.]
# (step=3, k=107) bar_lmbdk: 4.912691269126913
# (step=3, k=107) lmbdk: 4.912691269126913
# (step=3, k=107) Factible: True
# (step=3, k=107) xk: [-5.          0.08730873]
# (step=3, k=107) f(xk): 62100.21862708323
#
# (step=1, k=108) A1.index: [False  True False False]
# (step=1, k=108) A2.index: [ True False  True  True]
# (step=2, k=108) dk: [1. 1.]
# (step=3, k=108) bar_lmbdk: 4.912691269126913
# (step=3, k=108) lmbdk: 4.912691269126913
# (step=3, k=108) Factible: True
# (step=3, k=108) xk: [-0.08730873  5.        ]
# (step=3, k=108) f(xk): 2493.565236519634
#
# (step=1, k=109) A1.index: [False False  True False]
# (step=1, k=109) A2.index: [ True  True False  True]
# (step=2, k=109) dk: [-1. -1.]
# (step=3, k=109) bar_lmbdk: 4.912691269126913
# (step=3, k=109) lmbdk: 4.912691269126913
# (step=3, k=109) Factible: True
# (step=3, k=109) xk: [-5.          0.08730873]
# (step=3, k=109) f(xk): 62100.21862708323
#
# (step=1, k=110) A1.index: [False  True False False]
# (step=1, k=110) A2.index: [ True False  True  True]
# (step=2, k=110) dk: [1. 1.]
# (step=3, k=110) bar_lmbdk: 4.912691269126913
# (step=3, k=110) lmbdk: 4.912691269126913
# (step=3, k=110) Factible: True
# (step=3, k=110) xk: [-0.08730873  5.        ]
# (step=3, k=110) f(xk): 2493.565236519634
#
# (step=1, k=111) A1.index: [False False  True False]
# (step=1, k=111) A2.index: [ True  True False  True]
# (step=2, k=111) dk: [-1. -1.]
# (step=3, k=111) bar_lmbdk: 4.912691269126913
# (step=3, k=111) lmbdk: 4.912691269126913
# (step=3, k=111) Factible: True
# (step=3, k=111) xk: [-5.          0.08730873]
# (step=3, k=111) f(xk): 62100.21862708323
#
# (step=1, k=112) A1.index: [False  True False False]
# (step=1, k=112) A2.index: [ True False  True  True]
# (step=2, k=112) dk: [1. 1.]
# (step=3, k=112) bar_lmbdk: 4.912691269126913
# (step=3, k=112) lmbdk: 4.912691269126913
# (step=3, k=112) Factible: True
# (step=3, k=112) xk: [-0.08730873  5.        ]
# (step=3, k=112) f(xk): 2493.565236519634
#
# (step=1, k=113) A1.index: [False False  True False]
# (step=1, k=113) A2.index: [ True  True False  True]
# (step=2, k=113) dk: [-1. -1.]
# (step=3, k=113) bar_lmbdk: 4.912691269126913
# (step=3, k=113) lmbdk: 4.912691269126913
# (step=3, k=113) Factible: True
# (step=3, k=113) xk: [-5.          0.08730873]
# (step=3, k=113) f(xk): 62100.21862708323
#
# (step=1, k=114) A1.index: [False  True False False]
# (step=1, k=114) A2.index: [ True False  True  True]
# (step=2, k=114) dk: [1. 1.]
# (step=3, k=114) bar_lmbdk: 4.912691269126913
# (step=3, k=114) lmbdk: 4.912691269126913
# (step=3, k=114) Factible: True
# (step=3, k=114) xk: [-0.08730873  5.        ]
# (step=3, k=114) f(xk): 2493.565236519634
#
# (step=1, k=115) A1.index: [False False  True False]
# (step=1, k=115) A2.index: [ True  True False  True]
# (step=2, k=115) dk: [-1. -1.]
# (step=3, k=115) bar_lmbdk: 4.912691269126913
# (step=3, k=115) lmbdk: 4.912691269126913
# (step=3, k=115) Factible: True
# (step=3, k=115) xk: [-5.          0.08730873]
# (step=3, k=115) f(xk): 62100.21862708323
#
# (step=1, k=116) A1.index: [False  True False False]
# (step=1, k=116) A2.index: [ True False  True  True]
# (step=2, k=116) dk: [1. 1.]
# (step=3, k=116) bar_lmbdk: 4.912691269126913
# (step=3, k=116) lmbdk: 4.912691269126913
# (step=3, k=116) Factible: True
# (step=3, k=116) xk: [-0.08730873  5.        ]
# (step=3, k=116) f(xk): 2493.565236519634
#
# (step=1, k=117) A1.index: [False False  True False]
# (step=1, k=117) A2.index: [ True  True False  True]
# (step=2, k=117) dk: [-1. -1.]
# (step=3, k=117) bar_lmbdk: 4.912691269126913
# (step=3, k=117) lmbdk: 4.912691269126913
# (step=3, k=117) Factible: True
# (step=3, k=117) xk: [-5.          0.08730873]
# (step=3, k=117) f(xk): 62100.21862708323
#
# (step=1, k=118) A1.index: [False  True False False]
# (step=1, k=118) A2.index: [ True False  True  True]
# (step=2, k=118) dk: [1. 1.]
# (step=3, k=118) bar_lmbdk: 4.912691269126913
# (step=3, k=118) lmbdk: 4.912691269126913
# (step=3, k=118) Factible: True
# (step=3, k=118) xk: [-0.08730873  5.        ]
# (step=3, k=118) f(xk): 2493.565236519634
#
# (step=1, k=119) A1.index: [False False  True False]
# (step=1, k=119) A2.index: [ True  True False  True]
# (step=2, k=119) dk: [-1. -1.]
# (step=3, k=119) bar_lmbdk: 4.912691269126913
# (step=3, k=119) lmbdk: 4.912691269126913
# (step=3, k=119) Factible: True
# (step=3, k=119) xk: [-5.          0.08730873]
# (step=3, k=119) f(xk): 62100.21862708323
#
# (step=1, k=120) A1.index: [False  True False False]
# (step=1, k=120) A2.index: [ True False  True  True]
# (step=2, k=120) dk: [1. 1.]
# (step=3, k=120) bar_lmbdk: 4.912691269126913
# (step=3, k=120) lmbdk: 4.912691269126913
# (step=3, k=120) Factible: True
# (step=3, k=120) xk: [-0.08730873  5.        ]
# (step=3, k=120) f(xk): 2493.565236519634
#
# (step=1, k=121) A1.index: [False False  True False]
# (step=1, k=121) A2.index: [ True  True False  True]
# (step=2, k=121) dk: [-1. -1.]
# (step=3, k=121) bar_lmbdk: 4.912691269126913
# (step=3, k=121) lmbdk: 4.912691269126913
# (step=3, k=121) Factible: True
# (step=3, k=121) xk: [-5.          0.08730873]
# (step=3, k=121) f(xk): 62100.21862708323
#
# (step=1, k=122) A1.index: [False  True False False]
# (step=1, k=122) A2.index: [ True False  True  True]
# (step=2, k=122) dk: [1. 1.]
# (step=3, k=122) bar_lmbdk: 4.912691269126913
# (step=3, k=122) lmbdk: 4.912691269126913
# (step=3, k=122) Factible: True
# (step=3, k=122) xk: [-0.08730873  5.        ]
# (step=3, k=122) f(xk): 2493.565236519634
#
# (step=1, k=123) A1.index: [False False  True False]
# (step=1, k=123) A2.index: [ True  True False  True]
# (step=2, k=123) dk: [-1. -1.]
# (step=3, k=123) bar_lmbdk: 4.912691269126913
# (step=3, k=123) lmbdk: 4.912691269126913
# (step=3, k=123) Factible: True
# (step=3, k=123) xk: [-5.          0.08730873]
# (step=3, k=123) f(xk): 62100.21862708323
#
# (step=1, k=124) A1.index: [False  True False False]
# (step=1, k=124) A2.index: [ True False  True  True]
# (step=2, k=124) dk: [1. 1.]
# (step=3, k=124) bar_lmbdk: 4.912691269126913
# (step=3, k=124) lmbdk: 4.912691269126913
# (step=3, k=124) Factible: True
# (step=3, k=124) xk: [-0.08730873  5.        ]
# (step=3, k=124) f(xk): 2493.565236519634
#
# (step=1, k=125) A1.index: [False False  True False]
# (step=1, k=125) A2.index: [ True  True False  True]
# (step=2, k=125) dk: [-1. -1.]
# (step=3, k=125) bar_lmbdk: 4.912691269126913
# (step=3, k=125) lmbdk: 4.912691269126913
# (step=3, k=125) Factible: True
# (step=3, k=125) xk: [-5.          0.08730873]
# (step=3, k=125) f(xk): 62100.21862708323
#
# (step=1, k=126) A1.index: [False  True False False]
# (step=1, k=126) A2.index: [ True False  True  True]
# (step=2, k=126) dk: [1. 1.]
# (step=3, k=126) bar_lmbdk: 4.912691269126913
# (step=3, k=126) lmbdk: 4.912691269126913
# (step=3, k=126) Factible: True
# (step=3, k=126) xk: [-0.08730873  5.        ]
# (step=3, k=126) f(xk): 2493.565236519634
#
# (step=1, k=127) A1.index: [False False  True False]
# (step=1, k=127) A2.index: [ True  True False  True]
# (step=2, k=127) dk: [-1. -1.]
# (step=3, k=127) bar_lmbdk: 4.912691269126913
# (step=3, k=127) lmbdk: 4.912691269126913
# (step=3, k=127) Factible: True
# (step=3, k=127) xk: [-5.          0.08730873]
# (step=3, k=127) f(xk): 62100.21862708323
#
# (step=1, k=128) A1.index: [False  True False False]
# (step=1, k=128) A2.index: [ True False  True  True]
# (step=2, k=128) dk: [1. 1.]
# (step=3, k=128) bar_lmbdk: 4.912691269126913
# (step=3, k=128) lmbdk: 4.912691269126913
# (step=3, k=128) Factible: True
# (step=3, k=128) xk: [-0.08730873  5.        ]
# (step=3, k=128) f(xk): 2493.565236519634
#
# (step=1, k=129) A1.index: [False False  True False]
# (step=1, k=129) A2.index: [ True  True False  True]
# (step=2, k=129) dk: [-1. -1.]
# (step=3, k=129) bar_lmbdk: 4.912691269126913
# (step=3, k=129) lmbdk: 4.912691269126913
# (step=3, k=129) Factible: True
# (step=3, k=129) xk: [-5.          0.08730873]
# (step=3, k=129) f(xk): 62100.21862708323
#
# (step=1, k=130) A1.index: [False  True False False]
# (step=1, k=130) A2.index: [ True False  True  True]
# (step=2, k=130) dk: [1. 1.]
# (step=3, k=130) bar_lmbdk: 4.912691269126913
# (step=3, k=130) lmbdk: 4.912691269126913
# (step=3, k=130) Factible: True
# (step=3, k=130) xk: [-0.08730873  5.        ]
# (step=3, k=130) f(xk): 2493.565236519634
#
# (step=1, k=131) A1.index: [False False  True False]
# (step=1, k=131) A2.index: [ True  True False  True]
# (step=2, k=131) dk: [-1. -1.]
# (step=3, k=131) bar_lmbdk: 4.912691269126913
# (step=3, k=131) lmbdk: 4.912691269126913
# (step=3, k=131) Factible: True
# (step=3, k=131) xk: [-5.          0.08730873]
# (step=3, k=131) f(xk): 62100.21862708323
#
# (step=1, k=132) A1.index: [False  True False False]
# (step=1, k=132) A2.index: [ True False  True  True]
# (step=2, k=132) dk: [1. 1.]
# (step=3, k=132) bar_lmbdk: 4.912691269126913
# (step=3, k=132) lmbdk: 4.912691269126913
# (step=3, k=132) Factible: True
# (step=3, k=132) xk: [-0.08730873  5.        ]
# (step=3, k=132) f(xk): 2493.565236519634
#
# (step=1, k=133) A1.index: [False False  True False]
# (step=1, k=133) A2.index: [ True  True False  True]
# (step=2, k=133) dk: [-1. -1.]
# (step=3, k=133) bar_lmbdk: 4.912691269126913
# (step=3, k=133) lmbdk: 4.912691269126913
# (step=3, k=133) Factible: True
# (step=3, k=133) xk: [-5.          0.08730873]
# (step=3, k=133) f(xk): 62100.21862708323
#
# (step=1, k=134) A1.index: [False  True False False]
# (step=1, k=134) A2.index: [ True False  True  True]
# (step=2, k=134) dk: [1. 1.]
# (step=3, k=134) bar_lmbdk: 4.912691269126913
# (step=3, k=134) lmbdk: 4.912691269126913
# (step=3, k=134) Factible: True
# (step=3, k=134) xk: [-0.08730873  5.        ]
# (step=3, k=134) f(xk): 2493.565236519634
#
# (step=1, k=135) A1.index: [False False  True False]
# (step=1, k=135) A2.index: [ True  True False  True]
# (step=2, k=135) dk: [-1. -1.]
# (step=3, k=135) bar_lmbdk: 4.912691269126913
# (step=3, k=135) lmbdk: 4.912691269126913
# (step=3, k=135) Factible: True
# (step=3, k=135) xk: [-5.          0.08730873]
# (step=3, k=135) f(xk): 62100.21862708323
#
# (step=1, k=136) A1.index: [False  True False False]
# (step=1, k=136) A2.index: [ True False  True  True]
# (step=2, k=136) dk: [1. 1.]
# (step=3, k=136) bar_lmbdk: 4.912691269126913
# (step=3, k=136) lmbdk: 4.912691269126913
# (step=3, k=136) Factible: True
# (step=3, k=136) xk: [-0.08730873  5.        ]
# (step=3, k=136) f(xk): 2493.565236519634
#
# (step=1, k=137) A1.index: [False False  True False]
# (step=1, k=137) A2.index: [ True  True False  True]
# (step=2, k=137) dk: [-1. -1.]
# (step=3, k=137) bar_lmbdk: 4.912691269126913
# (step=3, k=137) lmbdk: 4.912691269126913
# (step=3, k=137) Factible: True
# (step=3, k=137) xk: [-5.          0.08730873]
# (step=3, k=137) f(xk): 62100.21862708323
#
# (step=1, k=138) A1.index: [False  True False False]
# (step=1, k=138) A2.index: [ True False  True  True]
# (step=2, k=138) dk: [1. 1.]
# (step=3, k=138) bar_lmbdk: 4.912691269126913
# (step=3, k=138) lmbdk: 4.912691269126913
# (step=3, k=138) Factible: True
# (step=3, k=138) xk: [-0.08730873  5.        ]
# (step=3, k=138) f(xk): 2493.565236519634
#
# (step=1, k=139) A1.index: [False False  True False]
# (step=1, k=139) A2.index: [ True  True False  True]
# (step=2, k=139) dk: [-1. -1.]
# (step=3, k=139) bar_lmbdk: 4.912691269126913
# (step=3, k=139) lmbdk: 4.912691269126913
# (step=3, k=139) Factible: True
# (step=3, k=139) xk: [-5.          0.08730873]
# (step=3, k=139) f(xk): 62100.21862708323
#
# (step=1, k=140) A1.index: [False  True False False]
# (step=1, k=140) A2.index: [ True False  True  True]
# (step=2, k=140) dk: [1. 1.]
# (step=3, k=140) bar_lmbdk: 4.912691269126913
# (step=3, k=140) lmbdk: 4.912691269126913
# (step=3, k=140) Factible: True
# (step=3, k=140) xk: [-0.08730873  5.        ]
# (step=3, k=140) f(xk): 2493.565236519634
#
# (step=1, k=141) A1.index: [False False  True False]
# (step=1, k=141) A2.index: [ True  True False  True]
# (step=2, k=141) dk: [-1. -1.]
# (step=3, k=141) bar_lmbdk: 4.912691269126913
# (step=3, k=141) lmbdk: 4.912691269126913
# (step=3, k=141) Factible: True
# (step=3, k=141) xk: [-5.          0.08730873]
# (step=3, k=141) f(xk): 62100.21862708323
#
# (step=1, k=142) A1.index: [False  True False False]
# (step=1, k=142) A2.index: [ True False  True  True]
# (step=2, k=142) dk: [1. 1.]
# (step=3, k=142) bar_lmbdk: 4.912691269126913
# (step=3, k=142) lmbdk: 4.912691269126913
# (step=3, k=142) Factible: True
# (step=3, k=142) xk: [-0.08730873  5.        ]
# (step=3, k=142) f(xk): 2493.565236519634
#
# (step=1, k=143) A1.index: [False False  True False]
# (step=1, k=143) A2.index: [ True  True False  True]
# (step=2, k=143) dk: [-1. -1.]
# (step=3, k=143) bar_lmbdk: 4.912691269126913
# (step=3, k=143) lmbdk: 4.912691269126913
# (step=3, k=143) Factible: True
# (step=3, k=143) xk: [-5.          0.08730873]
# ...
#
# (step=1, k=832) A1.index: [False  True False False]
# (step=1, k=832) A2.index: [ True False  True  True]
# (step=2, k=832) dk: [1. 1.]
# (step=3, k=832) bar_lmbdk: 4.912691269126913
# (step=3, k=832) lmbdk: 4.912691269126913
# (step=3, k=832) Factible: True
# (step=3, k=832) xk: [-0.08730873  5.        ]
# (step=3, k=832) f(xk): 2493.565236519634
#
# (step=1, k=833) A1.index: [False False  True False]
# (step=1, k=833) A2.index: [ True  True False  True]
# (step=2, k=833) dk: [-1. -1.]
# (step=3, k=833) bar_lmbdk: 4.912691269126913
# (step=3, k=833) lmbdk: 4.912691269126913
# (step=3, k=833) Factible: True
# (step=3, k=833) xk: [-5.          0.08730873]
# (step=3, k=833) f(xk): 62100.21862708323
#
# (step=1, k=834) A1.index: [False  True False False]
# (step=1, k=834) A2.index: [ True False  True  True]
# (step=2, k=834) dk: [1. 1.]
# (step=3, k=834) bar_lmbdk: 4.912691269126913
# (step=3, k=834) lmbdk: 4.912691269126913
# (step=3, k=834) Factible: True
# (step=3, k=834) xk: [-0.08730873  5.        ]
# (step=3, k=834) f(xk): 2493.565236519634
#
# (step=1, k=835) A1.index: [False False  True False]
# (step=1, k=835) A2.index: [ True  True False  True]
# (step=2, k=835) dk: [-1. -1.]
# (step=3, k=835) bar_lmbdk: 4.912691269126913
# (step=3, k=835) lmbdk: 4.912691269126913
# (step=3, k=835) Factible: True
# (step=3, k=835) xk: [-5.          0.08730873]
# (step=3, k=835) f(xk): 62100.21862708323
#
# (step=1, k=836) A1.index: [False  True False False]
# (step=1, k=836) A2.index: [ True False  True  True]
# (step=2, k=836) dk: [1. 1.]
# (step=3, k=836) bar_lmbdk: 4.912691269126913
# (step=3, k=836) lmbdk: 4.912691269126913
# (step=3, k=836) Factible: True
# (step=3, k=836) xk: [-0.08730873  5.        ]
# (step=3, k=836) f(xk): 2493.565236519634
#
# (step=1, k=837) A1.index: [False False  True False]
# (step=1, k=837) A2.index: [ True  True False  True]
# (step=2, k=837) dk: [-1. -1.]
# (step=3, k=837) bar_lmbdk: 4.912691269126913
# (step=3, k=837) lmbdk: 4.912691269126913
# (step=3, k=837) Factible: True
# (step=3, k=837) xk: [-5.          0.08730873]
# (step=3, k=837) f(xk): 62100.21862708323
#
# (step=1, k=838) A1.index: [False  True False False]
# (step=1, k=838) A2.index: [ True False  True  True]
# (step=2, k=838) dk: [1. 1.]
# (step=3, k=838) bar_lmbdk: 4.912691269126913
# (step=3, k=838) lmbdk: 4.912691269126913
# (step=3, k=838) Factible: True
# (step=3, k=838) xk: [-0.08730873  5.        ]
# (step=3, k=838) f(xk): 2493.565236519634
#
# (step=1, k=839) A1.index: [False False  True False]
# (step=1, k=839) A2.index: [ True  True False  True]
# (step=2, k=839) dk: [-1. -1.]
# (step=3, k=839) bar_lmbdk: 4.912691269126913
# (step=3, k=839) lmbdk: 4.912691269126913
# (step=3, k=839) Factible: True
# (step=3, k=839) xk: [-5.          0.08730873]
# (step=3, k=839) f(xk): 62100.21862708323
#
# (step=1, k=840) A1.index: [False  True False False]
# (step=1, k=840) A2.index: [ True False  True  True]
# (step=2, k=840) dk: [1. 1.]
# (step=3, k=840) bar_lmbdk: 4.912691269126913
# (step=3, k=840) lmbdk: 4.912691269126913
# (step=3, k=840) Factible: True
# (step=3, k=840) xk: [-0.08730873  5.        ]
# (step=3, k=840) f(xk): 2493.565236519634
#
# (step=1, k=841) A1.index: [False False  True False]
# (step=1, k=841) A2.index: [ True  True False  True]
# (step=2, k=841) dk: [-1. -1.]
# (step=3, k=841) bar_lmbdk: 4.912691269126913
# (step=3, k=841) lmbdk: 4.912691269126913
# (step=3, k=841) Factible: True
# (step=3, k=841) xk: [-5.          0.08730873]
# (step=3, k=841) f(xk): 62100.21862708323
#
# (step=1, k=842) A1.index: [False  True False False]
# (step=1, k=842) A2.index: [ True False  True  True]
# (step=2, k=842) dk: [1. 1.]
# (step=3, k=842) bar_lmbdk: 4.912691269126913
# (step=3, k=842) lmbdk: 4.912691269126913
# (step=3, k=842) Factible: True
# (step=3, k=842) xk: [-0.08730873  5.        ]
# (step=3, k=842) f(xk): 2493.565236519634
#
# (step=1, k=843) A1.index: [False False  True False]
# (step=1, k=843) A2.index: [ True  True False  True]
# (step=2, k=843) dk: [-1. -1.]
# (step=3, k=843) bar_lmbdk: 4.912691269126913
# (step=3, k=843) lmbdk: 4.912691269126913
# (step=3, k=843) Factible: True
# (step=3, k=843) xk: [-5.          0.08730873]
# (step=3, k=843) f(xk): 62100.21862708323
#
# (step=1, k=844) A1.index: [False  True False False]
# (step=1, k=844) A2.index: [ True False  True  True]
# (step=2, k=844) dk: [1. 1.]
# (step=3, k=844) bar_lmbdk: 4.912691269126913
# (step=3, k=844) lmbdk: 4.912691269126913
# (step=3, k=844) Factible: True
# (step=3, k=844) xk: [-0.08730873  5.        ]
# (step=3, k=844) f(xk): 2493.565236519634
#
# (step=1, k=845) A1.index: [False False  True False]
# (step=1, k=845) A2.index: [ True  True False  True]
# (step=2, k=845) dk: [-1. -1.]
# (step=3, k=845) bar_lmbdk: 4.912691269126913
# (step=3, k=845) lmbdk: 4.912691269126913
# (step=3, k=845) Factible: True
# (step=3, k=845) xk: [-5.          0.08730873]
# (step=3, k=845) f(xk): 62100.21862708323
#
# (step=1, k=846) A1.index: [False  True False False]
# (step=1, k=846) A2.index: [ True False  True  True]
# (step=2, k=846) dk: [1. 1.]
# (step=3, k=846) bar_lmbdk: 4.912691269126913
# (step=3, k=846) lmbdk: 4.912691269126913
# (step=3, k=846) Factible: True
# (step=3, k=846) xk: [-0.08730873  5.        ]
# (step=3, k=846) f(xk): 2493.565236519634
#
# (step=1, k=847) A1.index: [False False  True False]
# (step=1, k=847) A2.index: [ True  True False  True]
# (step=2, k=847) dk: [-1. -1.]
# (step=3, k=847) bar_lmbdk: 4.912691269126913
# (step=3, k=847) lmbdk: 4.912691269126913
# (step=3, k=847) Factible: True
# (step=3, k=847) xk: [-5.          0.08730873]
# (step=3, k=847) f(xk): 62100.21862708323
#
# (step=1, k=848) A1.index: [False  True False False]
# (step=1, k=848) A2.index: [ True False  True  True]
# (step=2, k=848) dk: [1. 1.]
# (step=3, k=848) bar_lmbdk: 4.912691269126913
# (step=3, k=848) lmbdk: 4.912691269126913
# (step=3, k=848) Factible: True
# (step=3, k=848) xk: [-0.08730873  5.        ]
# (step=3, k=848) f(xk): 2493.565236519634
#
# (step=1, k=849) A1.index: [False False  True False]
# (step=1, k=849) A2.index: [ True  True False  True]
# (step=2, k=849) dk: [-1. -1.]
# (step=3, k=849) bar_lmbdk: 4.912691269126913
# (step=3, k=849) lmbdk: 4.912691269126913
# (step=3, k=849) Factible: True
# (step=3, k=849) xk: [-5.          0.08730873]
# (step=3, k=849) f(xk): 62100.21862708323
#
# (step=1, k=850) A1.index: [False  True False False]
# (step=1, k=850) A2.index: [ True False  True  True]
# (step=2, k=850) dk: [1. 1.]
# (step=3, k=850) bar_lmbdk: 4.912691269126913
# (step=3, k=850) lmbdk: 4.912691269126913
# (step=3, k=850) Factible: True
# (step=3, k=850) xk: [-0.08730873  5.        ]
# (step=3, k=850) f(xk): 2493.565236519634
#
# (step=1, k=851) A1.index: [False False  True False]
# (step=1, k=851) A2.index: [ True  True False  True]
# (step=2, k=851) dk: [-1. -1.]
# (step=3, k=851) bar_lmbdk: 4.912691269126913
# (step=3, k=851) lmbdk: 4.912691269126913
# (step=3, k=851) Factible: True
# (step=3, k=851) xk: [-5.          0.08730873]
# (step=3, k=851) f(xk): 62100.21862708323
#
# (step=1, k=852) A1.index: [False  True False False]
# (step=1, k=852) A2.index: [ True False  True  True]
# (step=2, k=852) dk: [1. 1.]
# (step=3, k=852) bar_lmbdk: 4.912691269126913
# (step=3, k=852) lmbdk: 4.912691269126913
# (step=3, k=852) Factible: True
# (step=3, k=852) xk: [-0.08730873  5.        ]
# (step=3, k=852) f(xk): 2493.565236519634
#
# (step=1, k=853) A1.index: [False False  True False]
# (step=1, k=853) A2.index: [ True  True False  True]
# (step=2, k=853) dk: [-1. -1.]
# (step=3, k=853) bar_lmbdk: 4.912691269126913
# (step=3, k=853) lmbdk: 4.912691269126913
# (step=3, k=853) Factible: True
# (step=3, k=853) xk: [-5.          0.08730873]
# (step=3, k=853) f(xk): 62100.21862708323
#
# (step=1, k=854) A1.index: [False  True False False]
# (step=1, k=854) A2.index: [ True False  True  True]
# (step=2, k=854) dk: [1. 1.]
# (step=3, k=854) bar_lmbdk: 4.912691269126913
# (step=3, k=854) lmbdk: 4.912691269126913
# (step=3, k=854) Factible: True
# (step=3, k=854) xk: [-0.08730873  5.        ]
# (step=3, k=854) f(xk): 2493.565236519634
#
# (step=1, k=855) A1.index: [False False  True False]
# (step=1, k=855) A2.index: [ True  True False  True]
# (step=2, k=855) dk: [-1. -1.]
# (step=3, k=855) bar_lmbdk: 4.912691269126913
# (step=3, k=855) lmbdk: 4.912691269126913
# (step=3, k=855) Factible: True
# (step=3, k=855) xk: [-5.          0.08730873]
# (step=3, k=855) f(xk): 62100.21862708323
#
# (step=1, k=856) A1.index: [False  True False False]
# (step=1, k=856) A2.index: [ True False  True  True]
# (step=2, k=856) dk: [1. 1.]
# (step=3, k=856) bar_lmbdk: 4.912691269126913
# (step=3, k=856) lmbdk: 4.912691269126913
# (step=3, k=856) Factible: True
# (step=3, k=856) xk: [-0.08730873  5.        ]
# (step=3, k=856) f(xk): 2493.565236519634
#
# (step=1, k=857) A1.index: [False False  True False]
# (step=1, k=857) A2.index: [ True  True False  True]
# (step=2, k=857) dk: [-1. -1.]
# (step=3, k=857) bar_lmbdk: 4.912691269126913
# (step=3, k=857) lmbdk: 4.912691269126913
# (step=3, k=857) Factible: True
# (step=3, k=857) xk: [-5.          0.08730873]
# (step=3, k=857) f(xk): 62100.21862708323
#
# (step=1, k=858) A1.index: [False  True False False]
# (step=1, k=858) A2.index: [ True False  True  True]
# (step=2, k=858) dk: [1. 1.]
# (step=3, k=858) bar_lmbdk: 4.912691269126913
# (step=3, k=858) lmbdk: 4.912691269126913
# (step=3, k=858) Factible: True
# (step=3, k=858) xk: [-0.08730873  5.        ]
# (step=3, k=858) f(xk): 2493.565236519634
#
# (step=1, k=859) A1.index: [False False  True False]
# (step=1, k=859) A2.index: [ True  True False  True]
# (step=2, k=859) dk: [-1. -1.]
# (step=3, k=859) bar_lmbdk: 4.912691269126913
# (step=3, k=859) lmbdk: 4.912691269126913
# (step=3, k=859) Factible: True
# (step=3, k=859) xk: [-5.          0.08730873]
# (step=3, k=859) f(xk): 62100.21862708323
#
# (step=1, k=860) A1.index: [False  True False False]
# (step=1, k=860) A2.index: [ True False  True  True]
# (step=2, k=860) dk: [1. 1.]
# (step=3, k=860) bar_lmbdk: 4.912691269126913
# (step=3, k=860) lmbdk: 4.912691269126913
# (step=3, k=860) Factible: True
# (step=3, k=860) xk: [-0.08730873  5.        ]
# (step=3, k=860) f(xk): 2493.565236519634
#
# (step=1, k=861) A1.index: [False False  True False]
# (step=1, k=861) A2.index: [ True  True False  True]
# (step=2, k=861) dk: [-1. -1.]
# (step=3, k=861) bar_lmbdk: 4.912691269126913
# (step=3, k=861) lmbdk: 4.912691269126913
# (step=3, k=861) Factible: True
# (step=3, k=861) xk: [-5.          0.08730873]
# (step=3, k=861) f(xk): 62100.21862708323
#
# (step=1, k=862) A1.index: [False  True False False]
# (step=1, k=862) A2.index: [ True False  True  True]
# (step=2, k=862) dk: [1. 1.]
# (step=3, k=862) bar_lmbdk: 4.912691269126913
# (step=3, k=862) lmbdk: 4.912691269126913
# (step=3, k=862) Factible: True
# (step=3, k=862) xk: [-0.08730873  5.        ]
# (step=3, k=862) f(xk): 2493.565236519634
#
# (step=1, k=863) A1.index: [False False  True False]
# (step=1, k=863) A2.index: [ True  True False  True]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-157-5d6efd2769d4> in solve(self, x0, eps, N, sgm, verbose)
#     132             A1, A2, b1, b2 = step1(xk, self.A, self.b, verbose=verbose, k=k)
#     133             # Step 2: Resolver problema lineal (Dk)
# --> 134             obj = grad(xk)
#     135             dk, stop_grad = step2(obj, A1, self.E, eps, verbose=verbose, k=k)
#     136             stop = stop_grad
#
# ~\anaconda3\lib\site-packages\numdifftools\core.py in __call__(self, x, *args, **kwds)
#     488
#     489     def __call__(self, x, *args, **kwds):
# --> 490         result = super(Gradient, self).__call__(np.atleast_1d(x).ravel(), *args, **kwds)
#     491         if self.full_output:
#     492             return result[0].squeeze(), result[1]
#
# ~\anaconda3\lib\site-packages\numdifftools\core.py in __call__(self, x, *args, **kwds)
#     429
#     430     def __call__(self, x, *args, **kwds):
# --> 431         return super(Jacobian, self).__call__(np.atleast_1d(x), *args, **kwds)
#     432
#     433
#
# ~\anaconda3\lib\site-packages\numdifftools\core.py in __call__(self, x, *args, **kwds)
#     287         with np.errstate(divide='ignore', invalid='ignore'):
#     288             results, f_xi = self._derivative(x_i, args, kwds)
# --> 289             derivative, info = self._extrapolate(*results)
#     290         if self.full_output:
#     291             return derivative, self.info(f_xi, *info)
#
# ~\anaconda3\lib\site-packages\numdifftools\limits.py in _extrapolate(self, results, steps, shape)
#     202         if len(der1) > 2:
#     203             der1, errors1, steps = self._wynn_extrapolate(der1, steps)
# --> 204         der, info = self._get_best_estimate(der1, errors1, steps, shape)
#     205         return der, info
#     206
#
# ~\anaconda3\lib\site-packages\numdifftools\limits.py in _get_best_estimate(der, errors, steps, shape)
#     182     @staticmethod
#     183     def _get_best_estimate(der, errors, steps, shape):
# --> 184         errors += _Limit._add_error_to_outliers(der)
#     185         idx = _Limit._get_arg_min(errors)
#     186         final_step = steps.flat[idx].reshape(shape)
#
# ~\anaconda3\lib\site-packages\numdifftools\limits.py in _add_error_to_outliers(der, trim_fact)
#     165         """
#     166         try:
# --> 167             median = np.nanmedian(der, axis=0)
#     168             p75 = np.nanpercentile(der, 75, axis=0)
#     169             p25 = np.nanpercentile(der, 25, axis=0)
#
# <__array_function__ internals> in nanmedian(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in nanmedian(a, axis, out, overwrite_input, keepdims)
#    1111         return np.nanmean(a, axis, out=out, keepdims=keepdims)
#    1112
# -> 1113     r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
#    1114                                   overwrite_input=overwrite_input)
#    1115     if keepdims and keepdims is not np._NoValue:
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3513         keepdim = (1,) * a.ndim
#    3514
# -> 3515     r = func(a, **kwargs)
#    3516     return r, keepdim
#    3517
#
# ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in _nanmedian(a, axis, out, overwrite_input)
#     990         # benchmarked with shuffled (50, 50, x) containing a few NaN
#     991         if a.shape[axis] < 600:
# --> 992             return _nanmedian_small(a, axis, out, overwrite_input)
#     993         result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)
#     994         if out is not None:
#
# ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py in _nanmedian_small(a, axis, out, overwrite_input)
#    1005     """
#    1006     a = np.ma.masked_array(a, np.isnan(a))
# -> 1007     m = np.ma.median(a, axis=axis, overwrite_input=overwrite_input)
#    1008     for i in range(np.count_nonzero(m.mask.ravel())):
#    1009         warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ~\anaconda3\lib\site-packages\numpy\ma\extras.py in median(a, axis, out, overwrite_input, keepdims)
#     707             return m
#     708
# --> 709     r, k = _ureduce(a, func=_median, axis=axis, out=out,
#     710                     overwrite_input=overwrite_input)
#     711     if keepdims:
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3513         keepdim = (1,) * a.ndim
#    3514
# -> 3515     r = func(a, **kwargs)
#    3516     return r, keepdim
#    3517
#
# ~\anaconda3\lib\site-packages\numpy\ma\extras.py in _median(a, axis, out, overwrite_input)
#     774
#     775     # get low and high median
# --> 776     low_high = np.take_along_axis(asorted, lh, axis=axis)
#     777
#     778     def replace_masked(s):
#
# <__array_function__ internals> in take_along_axis(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py in take_along_axis(arr, indices, axis)
#     168
#     169     # use the fancy index
# --> 170     return arr[_make_along_axis_idx(arr_shape, indices, axis)]
#     171
#     172
#
# ~\anaconda3\lib\site-packages\numpy\ma\core.py in __getitem__(self, indx)
#    3218         # mask of being reshaped if it hasn't been set up properly yet
#    3219         # So it's easier to stick to the current version
# -> 3220         dout = self.data[indx]
#    3221         _mask = self._mask
#    3222
#
# KeyboardInterrupt:
